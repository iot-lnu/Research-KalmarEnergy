# %% [markdown]
# ## We start by Pricipal Componenets Analysis (PCA). It has 4 steps 1) Data Standardization 2) Calculate the Covariance 3) Find the principal components 4) Transform the data (Visualization and Analysis). But first we need to do: 1) Data consolidation and 2) Data Pre-processing and cleaning.

# %% [markdown]
# ## Data Consolidation: combine the five CSV files into a single dataset. Add a 'YEAR' column to keep track of the year each record is from.

# %%
# !pip install pandas

# %%
import pandas as pd

# Step 1: Read all CSV files into DataFrames with ISO-8859-1 encoding
df_2020 = pd.read_csv('lnu_2020.csv', encoding='ISO-8859-1')
df_2021 = pd.read_csv('lnu_2021.csv', encoding='ISO-8859-1')
df_2022 = pd.read_csv('lnu_2022.csv', encoding='ISO-8859-1')
df_2023 = pd.read_csv('lnu_2023.csv', encoding='ISO-8859-1')

# %%
# Step 2: Rename columns for the 2023 datasets
df_2023.columns = df_2023.columns.str.replace('VALUE_', 'HOUR_')

df_2023 = df_2023.rename(columns={'ID_FROM_DATE': 'DATE'})

# %%
df_2023
# Out:
#            CUSTOMER         AREA ISPRIVATEPERSON        DATE  HOUR_0  HOUR_1  \
# 0        1060598736  Kvarnholmen             Nej  2023-01-01   0.006   0.006
# 1        1060598736  Kvarnholmen             Nej  2023-01-02   0.005   0.004
# 2        1060598736  Kvarnholmen             Nej  2023-01-03   0.004   0.004
# 3        1060598736  Kvarnholmen             Nej  2023-01-04   0.009   0.008
# 4        1060598736  Kvarnholmen             Nej  2023-01-05   0.006   0.006
# ...             ...          ...             ...         ...     ...     ...
# 2338283  2411311923       Malmen              Ja  2023-12-27   0.000   0.000
# 2338284  2411311923       Malmen              Ja  2023-12-28   0.000   0.000
# 2338285  2411311923       Malmen              Ja  2023-12-29   0.000   0.000
# 2338286  2411311923       Malmen              Ja  2023-12-30   0.000   0.000
# 2338287  2411311923       Malmen              Ja  2023-12-31   0.000   0.000
#
# ...

# %%
df_2022
# Out:
#           CUSTOMER         AREA ISPRIVATEPERSON        DATE  HOUR_0  HOUR_1  \
# 0       1060598736  Kvarnholmen             Nej  2022-01-01   0.010   0.010
# 1       1060598736  Kvarnholmen             Nej  2022-01-02   0.010   0.010
# 2       1060598736  Kvarnholmen             Nej  2022-01-03   0.009   0.010
# 3       1060598736  Kvarnholmen             Nej  2022-01-04   0.012   0.012
# 4       1060598736  Kvarnholmen             Nej  2022-01-05   0.010   0.010
# ...            ...          ...             ...         ...     ...     ...
# 691219  2261780064       Malmen              Ja  2022-12-27   0.000   0.000
# 691220  2261780064       Malmen              Ja  2022-12-28   0.000   0.000
# 691221  2261780064       Malmen              Ja  2022-12-29   0.000   0.000
# 691222  2261780064       Malmen              Ja  2022-12-30   0.000   0.000
# 691223  2261780064       Malmen              Ja  2022-12-31   0.000   0.000
#
# ...

# %%
df_2021
# Out:
#           CUSTOMER         AREA ISPRIVATEPERSON        DATE  HOUR_0  HOUR_1  \
# 0       1060598736  Kvarnholmen             Nej  2021-01-01   0.017   0.015
# 1       1060598736  Kvarnholmen             Nej  2021-01-02   0.015   0.015
# 2       1060598736  Kvarnholmen             Nej  2021-01-03   0.016   0.016
# 3       1060598736  Kvarnholmen             Nej  2021-01-04   0.016   0.016
# 4       1060598736  Kvarnholmen             Nej  2021-01-05   0.014   0.014
# ...            ...          ...             ...         ...     ...     ...
# 307679  2127668195        Berga              Ja  2021-12-27   0.000   0.000
# 307680  2127668195        Berga              Ja  2021-12-28   0.000   0.000
# 307681  2127668195        Berga              Ja  2021-12-29   0.000   0.000
# 307682  2127668195        Berga              Ja  2021-12-30   0.000   0.000
# 307683  2127668195        Berga              Ja  2021-12-31   0.000   0.000
#
# ...

# %%
df_2020
# Out:
#           CUSTOMER         AREA ISPRIVATEPERSON        DATE  HOUR_0  HOUR_1  \
# 0       1060598736  Kvarnholmen             Nej  2020-01-01   0.011   0.012
# 1       1060598736  Kvarnholmen             Nej  2020-01-02   0.010   0.009
# 2       1060598736  Kvarnholmen             Nej  2020-01-03   0.011   0.011
# 3       1060598736  Kvarnholmen             Nej  2020-01-04   0.010   0.009
# 4       1060598736  Kvarnholmen             Nej  2020-01-05   0.011   0.011
# ...            ...          ...             ...         ...     ...     ...
# 277604  1971547438       Malmen             Nej  2020-12-27   0.000   0.000
# 277605  1971547438       Malmen             Nej  2020-12-28   0.000   0.000
# 277606  1971547438       Malmen             Nej  2020-12-29   0.000   0.000
# 277607  1971547438       Malmen             Nej  2020-12-30   0.000   0.000
# 277608  1971547438       Malmen             Nej  2020-12-31   0.000   0.000
#
# ...

# %%
# Step 3: Add a 'YEAR' column and concatenate DataFrames
df_2020['YEAR'] = 2020
df_2021['YEAR'] = 2021
df_2022['YEAR'] = 2022
df_2023['YEAR'] = 2023

# Concatenate all DataFrames into one and reset the index
combined_df = pd.concat([df_2020, df_2021, df_2022, df_2023], ignore_index=True)

# Verify the combined DataFrame
print(combined_df.head())
# Out:
#      CUSTOMER         AREA ISPRIVATEPERSON        DATE  HOUR_0  HOUR_1  \
# 0  1060598736  Kvarnholmen             Nej  2020-01-01   0.011   0.012
# 1  1060598736  Kvarnholmen             Nej  2020-01-02   0.010   0.009
# 2  1060598736  Kvarnholmen             Nej  2020-01-03   0.011   0.011
# 3  1060598736  Kvarnholmen             Nej  2020-01-04   0.010   0.009
# 4  1060598736  Kvarnholmen             Nej  2020-01-05   0.011   0.011
#
#    HOUR_2  HOUR_3  HOUR_4  HOUR_5  ...  HOUR_15  HOUR_16  HOUR_17  HOUR_18  \
# 0   0.012   0.012   0.013   0.012  ...    0.010    0.009    0.010    0.010
# 1   0.009   0.009   0.010   0.009  ...    0.009    0.009    0.010    0.010
# 2   0.011   0.010   0.010   0.010  ...    0.010    0.010    0.011    0.011
# 3   0.009   0.009   0.010   0.009  ...    0.011    0.011    0.012    0.008
# 4   0.010   0.011   0.011   0.011  ...    0.012    0.011    0.012    0.011
#
#    HOUR_19  HOUR_20  HOUR_21  HOUR_22  HOUR_23  YEAR
# ...

# %%
combined_df
# Out:
#            CUSTOMER         AREA ISPRIVATEPERSON        DATE  HOUR_0  HOUR_1  \
# 0        1060598736  Kvarnholmen             Nej  2020-01-01   0.011   0.012
# 1        1060598736  Kvarnholmen             Nej  2020-01-02   0.010   0.009
# 2        1060598736  Kvarnholmen             Nej  2020-01-03   0.011   0.011
# 3        1060598736  Kvarnholmen             Nej  2020-01-04   0.010   0.009
# 4        1060598736  Kvarnholmen             Nej  2020-01-05   0.011   0.011
# ...             ...          ...             ...         ...     ...     ...
# 3614800  2411311923       Malmen              Ja  2023-12-27   0.000   0.000
# 3614801  2411311923       Malmen              Ja  2023-12-28   0.000   0.000
# 3614802  2411311923       Malmen              Ja  2023-12-29   0.000   0.000
# 3614803  2411311923       Malmen              Ja  2023-12-30   0.000   0.000
# 3614804  2411311923       Malmen              Ja  2023-12-31   0.000   0.000
#
# ...

# %%
# Step 4: Correct any values which uses any different character like Stensö
# Replace 'Stensˆ' with 'Stensö' in the 'AREA' column
combined_df['AREA'] = combined_df['AREA'].replace('Stensˆ', 'Stensö')
combined_df['AREA'] = combined_df['AREA'].replace('StensÃ¶', 'Stensö')

# Verify the change
unique_areas = combined_df['AREA'].unique()
print(f"Unique AREA values: {unique_areas}")
# Out:
# Unique AREA values: ['Kvarnholmen' 'Malmen' 'Berga' 'Stensö']

# %% [markdown]
# ## Data Cleaning and Pre-processing:
#     Check for missing or inconsistent data and decide how to handle it (e.g., imputation or removal).
#     Ensure that all data types are correct (e.g., DATE should be a date type, HOUR_0 to HOUR_23 should be numeric). For example, for applying Imputation on non-numeric data (objects) for handling Nan values, first we need to convert them to a numeric. However, HOUR_0 to HOUR_23 were by default float.
#     Convert categorical variables like ISPRIVATEPERSON into a numerical form that PCA can work with, using encoding methods like One-Hot Encoding or Label Encoding.
#     Exclude non-numeric columns like CUSTOMER and AREA from PCA, or find a way to numerically encode them if they are relevant to your analysis.

# %%
# Check the data types for each DataFrame
print('Data types for df_2020:')
print(df_2020.dtypes)
print('\nData types for df_2021:')
print(df_2021.dtypes)
print('\nData types for df_2022:')
print(df_2022.dtypes)
print('\nData types for df_2023:')
print(df_2023.dtypes)
# Out:
# Data types for df_2020:
# CUSTOMER             int64
# AREA                object
# ISPRIVATEPERSON     object
# DATE                object
# HOUR_0             float64
# HOUR_1             float64
# HOUR_2             float64
# HOUR_3             float64
# HOUR_4             float64
# HOUR_5             float64
# HOUR_6             float64
# HOUR_7             float64
# HOUR_8             float64
# HOUR_9             float64
# HOUR_10            float64
# HOUR_11            float64
# HOUR_12            float64
# HOUR_13            float64
# HOUR_14            float64
# HOUR_15            float64
# HOUR_16            float64
# HOUR_17            float64
# HOUR_18            float64
# HOUR_19            float64
# HOUR_20            float64
# HOUR_21            float64
# HOUR_22            float64
# HOUR_23            float64
# YEAR                 int64
# dtype: object
#
# Data types for df_2021:
# CUSTOMER             int64
# AREA                object
# ISPRIVATEPERSON     object
# ...

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# Convert 'DATE' to datetime format
combined_df['DATE'] = pd.to_datetime(combined_df['DATE'])

# %%
# Count NaN values in each DataFrame
nan_count_2020 = df_2020.isna().sum().sum()
nan_count_2021 = df_2021.isna().sum().sum()
nan_count_2022 = df_2022.isna().sum().sum()
nan_count_2023 = df_2023.isna().sum().sum()

print(f"NaN values in 2020 DataFrame: {nan_count_2020}")
print(f"NaN values in 2021 DataFrame: {nan_count_2021}")
print(f"NaN values in 2022 DataFrame: {nan_count_2022}")
print(f"NaN values in 2023 DataFrame: {nan_count_2023}")
# Out:
# NaN values in 2020 DataFrame: 12365
# NaN values in 2021 DataFrame: 29255
# NaN values in 2022 DataFrame: 7039
# NaN values in 2023 DataFrame: 0

# %%
# Find rows and columns with NaN values in each DataFrame
nan_rows_columns_2020 = df_2020[df_2020.isna().any(axis=1)]
nan_rows_columns_2021 = df_2021[df_2021.isna().any(axis=1)]
nan_rows_columns_2022 = df_2022[df_2022.isna().any(axis=1)]
nan_rows_columns_2023 = df_2023[df_2023.isna().any(axis=1)]

print("Rows and columns with NaN values in 2020 DataFrame:")
print(nan_rows_columns_2020)
print("\nRows and columns with NaN values in 2021 DataFrame:")
print(nan_rows_columns_2021)
print("\nRows and columns with NaN values in 2022 DataFrame:")
print(nan_rows_columns_2022)
print("\nRows and columns with NaN values in 2023 DataFrame:")
print(nan_rows_columns_2023)
# Out:
# Rows and columns with NaN values in 2020 DataFrame:
#           CUSTOMER         AREA ISPRIVATEPERSON        DATE  HOUR_0  HOUR_1  \
# 3744    1060598943  Kvarnholmen             Nej  2020-01-10     NaN     NaN
# 8245    1060599104  Kvarnholmen             Nej  2020-05-06     NaN     NaN
# 9584    1060599315  Kvarnholmen             Nej  2020-01-02   0.003   0.003
# 9585    1060599315  Kvarnholmen             Nej  2020-01-08     NaN     NaN
# 13970   1060599939  Kvarnholmen             Nej  2020-06-17     NaN     NaN
# ...            ...          ...             ...         ...     ...     ...
# 277190  1969676870        Berga             Nej  2020-11-30     NaN     NaN
# 277222  1969676874        Berga             Nej  2020-11-19     NaN     NaN
# 277265  1969676878        Berga             Nej  2020-11-17     NaN     NaN
# 277310  1969676882        Berga             Nej  2020-11-17     NaN     NaN
# 277355  1969676886        Berga             Nej  2020-11-17     NaN     NaN
#
# ...

# %%
# Columns with NaN values in each DataFrame
nan_columns_2020 = df_2020.columns[df_2020.isna().any()].tolist()
nan_columns_2021 = df_2021.columns[df_2021.isna().any()].tolist()
nan_columns_2022 = df_2022.columns[df_2022.isna().any()].tolist()
nan_columns_2023 = df_2023.columns[df_2023.isna().any()].tolist()

print(f"Columns with NaN values in 2020 DataFrame: {nan_columns_2020}")
print(f"Columns with NaN values in 2021 DataFrame: {nan_columns_2021}")
print(f"Columns with NaN values in 2022 DataFrame: {nan_columns_2022}")
print(f"Columns with NaN values in 2023 DataFrame: {nan_columns_2023}")
# Out:
# Columns with NaN values in 2020 DataFrame: ['HOUR_0', 'HOUR_1', 'HOUR_2', 'HOUR_3', 'HOUR_4', 'HOUR_5', 'HOUR_6', 'HOUR_7', 'HOUR_8', 'HOUR_9', 'HOUR_10', 'HOUR_11', 'HOUR_12', 'HOUR_13', 'HOUR_14', 'HOUR_15', 'HOUR_16', 'HOUR_17', 'HOUR_18', 'HOUR_19', 'HOUR_20', 'HOUR_21', 'HOUR_22', 'HOUR_23']
# Columns with NaN values in 2021 DataFrame: ['HOUR_0', 'HOUR_1', 'HOUR_2', 'HOUR_3', 'HOUR_4', 'HOUR_5', 'HOUR_6', 'HOUR_7', 'HOUR_8', 'HOUR_9', 'HOUR_10', 'HOUR_11', 'HOUR_12', 'HOUR_13', 'HOUR_14', 'HOUR_15', 'HOUR_16', 'HOUR_17', 'HOUR_18', 'HOUR_19', 'HOUR_20', 'HOUR_21', 'HOUR_22', 'HOUR_23']
# Columns with NaN values in 2022 DataFrame: ['HOUR_0', 'HOUR_1', 'HOUR_2', 'HOUR_3', 'HOUR_4', 'HOUR_5', 'HOUR_6', 'HOUR_7', 'HOUR_8', 'HOUR_9', 'HOUR_10', 'HOUR_11', 'HOUR_12', 'HOUR_13', 'HOUR_14', 'HOUR_15', 'HOUR_16', 'HOUR_17', 'HOUR_18', 'HOUR_19', 'HOUR_20', 'HOUR_21', 'HOUR_22', 'HOUR_23']
# Columns with NaN values in 2023 DataFrame: []

# %% [markdown]
# ## Plot boxplot hourly power usage per year to see the outliers (High values compared to the power usage threshold which I defined for Residential:0.05MWh and Commercial:15MWh, negative values, and Nan values)

# %%
import matplotlib.pyplot as plt

# List of DataFrames for iteration
dfs = [df_2020, df_2021, df_2022, df_2023]
years = ['2020', '2021', '2022', '2023']

# Plotting boxplots for each DataFrame
for df, year in zip(dfs, years):
    # Selecting only the hour columns
    hours_data = df.filter(regex='^HOUR_')
    
    # Plotting
    plt.figure(figsize=(15, 5))
    hours_data.boxplot()
    plt.title(f'Hourly Power Consumption Boxplot for {year}')
    plt.ylabel('Power Consumption (MWh)')
    plt.xlabel('Hour of the Day')
    plt.xticks(rotation=90)
    plt.grid(False)
    plt.show()

# %% [markdown]
# ## ROW-WISE MEAN IMPUTATION

# %% [markdown]
# ## Mean Imputation is by default column-wise which means imputation strategy will replace missing values (NaNs) with the mean value of the respective column.
# ## Apply row-wise Mean Imputation which means: replacing all the outliers: (High values compared to the power usage threshold which I defined for Residential:0.03MWh and Commercial:3MWh, negative values, and Nan values).

# %% [markdown]
# ## If we are still seeing null values after performing the row-wise mean imputation, it could be due to that all values in a row are NaN or invalid: If an entire row (for all the hourly columns) consists of NaN or invalid values, the mean would also be NaN since there are no valid values to calculate the mean from. Ex: Customer id 1060676202 in 2020 Solution: define the minimum number of non-NaN hourly values required to keep a row.

# %%
# !pip install numpy

# %%
def replace_invalid_with_row_mean(df, residential_threshold, commercial_threshold, min_non_nan=3):
    # Operate only on the hour columns
    hour_columns = [f'HOUR_{i}' for i in range(24)]
    
    # Filter out rows that don't meet the threshold for non-NaN values
    df_filtered = df.dropna(thresh=min_non_nan, subset=hour_columns)
    
    # Copy the filtered DataFrame to avoid changing the original data
    df_copy = df_filtered.copy()
    
    # Determine thresholds based on customer type
    thresholds = df_copy['ISPRIVATEPERSON'].map(lambda x: residential_threshold if x == 'Ja' else commercial_threshold)
    
    # Mask the values that are either above their respective thresholds or negative
    df_copy[hour_columns] = df_copy[hour_columns].mask((df_copy[hour_columns] < 0) | (df_copy[hour_columns].gt(thresholds, axis=0)))
    
    # Calculate the mean for each row excluding NaNs
    row_means = df_copy[hour_columns].mean(axis=1)
    
    # Replace NaNs with the row's mean
    df_copy[hour_columns] = df_copy[hour_columns].apply(lambda x: x.fillna(row_means[x.name]), axis=1)
    
    return df_copy

# Define your thresholds
residential_threshold = 0.03  # 0.03 MWh for residential
commercial_threshold = 3      # 3 MWh for commercial

# Define the minimum number of non-NaN hourly values required to keep a row
min_non_nan_values = 3

# Apply the function to each DataFrame
df_2020_cleaned = replace_invalid_with_row_mean(df_2020, residential_threshold, commercial_threshold, min_non_nan_values)
df_2021_cleaned = replace_invalid_with_row_mean(df_2021, residential_threshold, commercial_threshold, min_non_nan_values)
df_2022_cleaned = replace_invalid_with_row_mean(df_2022, residential_threshold, commercial_threshold, min_non_nan_values)
df_2023_cleaned = replace_invalid_with_row_mean(df_2023, residential_threshold, commercial_threshold, min_non_nan_values)

# %%
df_2020_cleaned.isnull().sum()
# Out:
# CUSTOMER           0
# AREA               0
# ISPRIVATEPERSON    0
# DATE               0
# HOUR_0             0
# HOUR_1             0
# HOUR_2             0
# HOUR_3             0
# HOUR_4             0
# HOUR_5             0
# HOUR_6             0
# HOUR_7             0
# HOUR_8             0
# HOUR_9             0
# HOUR_10            0
# HOUR_11            0
# HOUR_12            0
# HOUR_13            0
# HOUR_14            0
# HOUR_15            0
# HOUR_16            0
# HOUR_17            0
# HOUR_18            0
# HOUR_19            0
# HOUR_20            0
# HOUR_21            0
# HOUR_22            0
# HOUR_23            0
# YEAR               0
# dtype: int64

# %%
df_2021_cleaned.isnull().sum()
# Out:
# CUSTOMER           0
# AREA               0
# ISPRIVATEPERSON    0
# DATE               0
# HOUR_0             0
# HOUR_1             0
# HOUR_2             0
# HOUR_3             0
# HOUR_4             0
# HOUR_5             0
# HOUR_6             0
# HOUR_7             0
# HOUR_8             0
# HOUR_9             0
# HOUR_10            0
# HOUR_11            0
# HOUR_12            0
# HOUR_13            0
# HOUR_14            0
# HOUR_15            0
# HOUR_16            0
# HOUR_17            0
# HOUR_18            0
# HOUR_19            0
# HOUR_20            0
# HOUR_21            0
# HOUR_22            0
# HOUR_23            0
# YEAR               0
# dtype: int64

# %%
df_2022_cleaned.isnull().sum()
# Out:
# CUSTOMER           0
# AREA               0
# ISPRIVATEPERSON    0
# DATE               0
# HOUR_0             0
# HOUR_1             0
# HOUR_2             0
# HOUR_3             0
# HOUR_4             0
# HOUR_5             0
# HOUR_6             0
# HOUR_7             0
# HOUR_8             0
# HOUR_9             0
# HOUR_10            0
# HOUR_11            0
# HOUR_12            0
# HOUR_13            0
# HOUR_14            0
# HOUR_15            0
# HOUR_16            0
# HOUR_17            0
# HOUR_18            0
# HOUR_19            0
# HOUR_20            0
# HOUR_21            0
# HOUR_22            0
# HOUR_23            0
# YEAR               0
# dtype: int64

# %%
df_2023_cleaned.isnull().sum()
# Out:
# CUSTOMER           0
# AREA               0
# ISPRIVATEPERSON    0
# DATE               0
# HOUR_0             0
# HOUR_1             0
# HOUR_2             0
# HOUR_3             0
# HOUR_4             0
# HOUR_5             0
# HOUR_6             0
# HOUR_7             0
# HOUR_8             0
# HOUR_9             0
# HOUR_10            0
# HOUR_11            0
# HOUR_12            0
# HOUR_13            0
# HOUR_14            0
# HOUR_15            0
# HOUR_16            0
# HOUR_17            0
# HOUR_18            0
# HOUR_19            0
# HOUR_20            0
# HOUR_21            0
# HOUR_22            0
# HOUR_23            0
# YEAR               0
# dtype: int64

# %%
# Concatenate all Cleaned DataFrames into one and reset the index
combined_df = pd.concat([df_2020_cleaned, df_2021_cleaned, df_2022_cleaned, df_2023_cleaned], ignore_index=True)

# %%
combined_df # Before row-wise imputation rules: 3614805 rows After row-wise imputation rules: 3612918
# Out:
#            CUSTOMER         AREA ISPRIVATEPERSON        DATE  HOUR_0  HOUR_1  \
# 0        1060598736  Kvarnholmen             Nej  2020-01-01   0.011   0.012
# 1        1060598736  Kvarnholmen             Nej  2020-01-02   0.010   0.009
# 2        1060598736  Kvarnholmen             Nej  2020-01-03   0.011   0.011
# 3        1060598736  Kvarnholmen             Nej  2020-01-04   0.010   0.009
# 4        1060598736  Kvarnholmen             Nej  2020-01-05   0.011   0.011
# ...             ...          ...             ...         ...     ...     ...
# 3612913  2411311923       Malmen              Ja  2023-12-27   0.000   0.000
# 3612914  2411311923       Malmen              Ja  2023-12-28   0.000   0.000
# 3612915  2411311923       Malmen              Ja  2023-12-29   0.000   0.000
# 3612916  2411311923       Malmen              Ja  2023-12-30   0.000   0.000
# 3612917  2411311923       Malmen              Ja  2023-12-31   0.000   0.000
#
# ...

# %% [markdown]
# ## Test if there is still any Nan values in the dataframe!

# %%
# Find rows in combined_df that still have any null values
rows_with_nan = combined_df[combined_df.isnull().any(axis=1)]

# Display the rows with NaN values
print(rows_with_nan)
# Out:
# Empty DataFrame
# Columns: [CUSTOMER, AREA, ISPRIVATEPERSON, DATE, HOUR_0, HOUR_1, HOUR_2, HOUR_3, HOUR_4, HOUR_5, HOUR_6, HOUR_7, HOUR_8, HOUR_9, HOUR_10, HOUR_11, HOUR_12, HOUR_13, HOUR_14, HOUR_15, HOUR_16, HOUR_17, HOUR_18, HOUR_19, HOUR_20, HOUR_21, HOUR_22, HOUR_23, YEAR]
# Index: []
#
# [0 rows x 29 columns]

# %% [markdown]
# ## Plot boxplot again to see the difference

# %%
import matplotlib.pyplot as plt

# List of DataFrames for iteration
dfs = [df_2020_cleaned, df_2021_cleaned, df_2022_cleaned, df_2023_cleaned]
years = ['2020', '2021', '2022', '2023']

# Plotting boxplots for each DataFrame
for df, year in zip(dfs, years):
    # Selecting only the hour columns
    hours_data = df.filter(regex='^HOUR_')
    
    # Plotting
    plt.figure(figsize=(15, 5))
    hours_data.boxplot()
    plt.title(f'Hourly Power Consumption Boxplot for {year}')
    plt.ylabel('Power Consumption (MWh)')
    plt.xlabel('Hour of the Day')
    plt.xticks(rotation=90)
    plt.grid(False)
    plt.show()

# %% [markdown]
# ## Visualization

# %%
# Number of customers in each year

total_unique_customers_2020 = df_2020_cleaned['CUSTOMER'].nunique()
print(f"Total number of unique customers: {total_unique_customers_2020}")

total_unique_customers_2021 = df_2021_cleaned['CUSTOMER'].nunique()
print(f"Total number of unique customers of 2021: {total_unique_customers_2021}")

total_unique_customers_2022 = df_2022_cleaned['CUSTOMER'].nunique()
print(f"Total number of unique customers of 2022: {total_unique_customers_2022}")

total_unique_customers_2023 = df_2023_cleaned['CUSTOMER'].nunique()
print(f"Total number of unique customers of 2023: {total_unique_customers_2023}")
# Out:
# Total number of unique customers: 814
# Total number of unique customers of 2021: 961
# Total number of unique customers of 2022: 6321
# Total number of unique customers of 2023: 6480

# %%
# Get unique customers for each year
customers_2020 = set(df_2020_cleaned['CUSTOMER'].unique())
customers_2021 = set(df_2021_cleaned['CUSTOMER'].unique())
customers_2022 = set(df_2022_cleaned['CUSTOMER'].unique())
customers_2023 = set(df_2023_cleaned['CUSTOMER'].unique())

# Check if 2023 covers all customers from 2020, 2021, and 2022
covers_2020 = customers_2023.issuperset(customers_2020)
covers_2021 = customers_2023.issuperset(customers_2021)
covers_2022 = customers_2023.issuperset(customers_2022)

all_covered = covers_2020 and covers_2021 and covers_2022

print(f"Do the customers of 2023 cover all customers from 2020? {covers_2020}")
print(f"Do the customers of 2023 cover all customers from 2021? {covers_2021}")
print(f"Do the customers of 2023 cover all customers from 2022? {covers_2022}")
print(f"Do the customers of 2023 cover all customers from 2020, 2021, and 2022? {all_covered}")
# Out:
# Do the customers of 2023 cover all customers from 2020? False
# Do the customers of 2023 cover all customers from 2021? False
# Do the customers of 2023 cover all customers from 2022? False
# Do the customers of 2023 cover all customers from 2020, 2021, and 2022? False

# %%
customers_2020
# Out:
# {1060598736,
#  1060598755,
#  1060598764,
#  1060598773,
#  1060598781,
#  1060598788,
#  1060598838,
#  1060598846,
#  1060598856,
#  1060598905,
#  1060598922,
#  1060598943,
#  1060598963,
#  1060598971,
#  1060598978,
#  1060599019,
#  1060599041,
#  1060599047,
#  1060599053,
#  1060599059,
#  1060599082,
#  1060599089,
#  1060599098,
#  1060599104,
#  1060599154,
#  1060599232,
#  1060599305,
#  1060599315,
#  1060599322,
#  1060599580,
#  1060599593,
#  1060599600,
#  1060599607,
#  1060599631,
#  1060599701,
#  1060599716,
#  1060599863,
#  1060599914,
#  1060599923,
#  1060599939,
#  1060600032,
#  1060600144,
#  1060600202,
#  1060600376,
#  1060600399,
#  1060600405,
#  1060600420,
#  1060600466,
#  1060600565,
#  1060600577,
#  1060600606,
#  1060600681,
#  1060600689,
#  1060600757,
#  1060600878,
#  1060600901,
#  1060600984,
#  1060601020,
#  1060601143,
#  1060601163,
#  1060601248,
#  1060601633,
#  1060601648,
#  1060601654,
#  1060601670,
#  1060601741,
# ...

# %%
customer_counts = combined_df.groupby('ISPRIVATEPERSON')['CUSTOMER'].nunique()
customer_counts
# Out:
# ISPRIVATEPERSON
# Ja     5097
# Nej    1388
# Name: CUSTOMER, dtype: int64

# %%
import matplotlib.pyplot as plt
customer_counts.plot(kind='bar')
plt.title('Number of Customers by Private Person Category')
plt.xlabel('Is Private Person')
plt.ylabel('Number of Customers')
plt.xticks(rotation=0)  # To keep the labels on the x-axis vertical
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you have loaded your data into a pandas DataFrame named 'data'
# Replace 'Nej' with 'Commercial', 'Ja' with 'Private', and map 'Unknown' or other values as needed
combined_df['ISPRIVATEPERSON'] = combined_df['ISPRIVATEPERSON'].map({
    'Nej': 'Commercial',
    'Ja': 'Residential',
})

# Now calculate the number of unique customers for the new categories
customer_counts = combined_df.groupby('ISPRIVATEPERSON')['CUSTOMER'].nunique()

# %%
# Now calculate the number of unique customers for the new categories
customer_counts = combined_df.groupby('ISPRIVATEPERSON')['CUSTOMER'].nunique()

# Plot the pie chart with the actual numbers and the total
total_customers = customer_counts.sum()
customer_counts.plot(kind='pie', autopct=lambda p: f'{p * total_customers / 100 :.0f}', startangle=90, labels=customer_counts.index)
plt.title(f'Customer Distribution by Category - Total: {total_customers}')
plt.ylabel('')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set the aesthetic style of the plots
sns.set_style("whitegrid")

# count unique customers per year split by category
customer_yearly = combined_df.groupby(['YEAR', 'ISPRIVATEPERSON'])['CUSTOMER'].nunique().unstack()

# Plot the stacked bar chart using seaborn
ax = customer_yearly.plot(kind='bar', stacked=True, legend=False)
# Display the total unique number of customers in combined dataframe
total_unique_customers = combined_df['CUSTOMER'].nunique()

plt.xlabel('Year')
plt.ylabel('Number of Unique Customers')

# Add labels on top of each stacked bar with the total number of customers for that year
for container in ax.containers:
    ax.bar_label(container, label_type='center')

# Move the legend outside of the plot
plt.legend(title='', bbox_to_anchor=(1.05, 1), loc='upper left')

# Add a title with the total unique customers
plt.title(f'Total Unique Customers: {total_unique_customers}')

plt.show()

# %%
combined_df.isnull().sum()
# Out:
# CUSTOMER           0
# AREA               0
# ISPRIVATEPERSON    0
# DATE               0
# HOUR_0             0
# HOUR_1             0
# HOUR_2             0
# HOUR_3             0
# HOUR_4             0
# HOUR_5             0
# HOUR_6             0
# HOUR_7             0
# HOUR_8             0
# HOUR_9             0
# HOUR_10            0
# HOUR_11            0
# HOUR_12            0
# HOUR_13            0
# HOUR_14            0
# HOUR_15            0
# HOUR_16            0
# HOUR_17            0
# HOUR_18            0
# HOUR_19            0
# HOUR_20            0
# HOUR_21            0
# HOUR_22            0
# HOUR_23            0
# YEAR               0
# dtype: int64

# %%
combined_df.isnull().mean()*100
# Out:
# CUSTOMER           0.0
# AREA               0.0
# ISPRIVATEPERSON    0.0
# DATE               0.0
# HOUR_0             0.0
# HOUR_1             0.0
# HOUR_2             0.0
# HOUR_3             0.0
# HOUR_4             0.0
# HOUR_5             0.0
# HOUR_6             0.0
# HOUR_7             0.0
# HOUR_8             0.0
# HOUR_9             0.0
# HOUR_10            0.0
# HOUR_11            0.0
# HOUR_12            0.0
# HOUR_13            0.0
# HOUR_14            0.0
# HOUR_15            0.0
# HOUR_16            0.0
# HOUR_17            0.0
# HOUR_18            0.0
# HOUR_19            0.0
# HOUR_20            0.0
# HOUR_21            0.0
# HOUR_22            0.0
# HOUR_23            0.0
# YEAR               0.0
# dtype: float64

# %%
# !pip install missingno

# %%
import missingno as msno
msno.matrix(combined_df)
# Out:
# <Axes: >

# %%
# !pip install scikit-learn

# %% [markdown]
# ## Create column 'One_Day_Power'

# %%
# Define the hourly columns
hourly_columns = [f'HOUR_{i}' for i in range(24)]

# Calculate the sum of the hourly consumption for each record and create a new column 'One_Day_Power'
combined_df['One_Day_Power'] = combined_df[hourly_columns].sum(axis=1)

# %%
print(combined_df[['One_Day_Power']].head())
# Out:
#    One_Day_Power
# 0          0.261
# 1          0.228
# 2          0.243
# 3          0.243
# 4          0.265

# %%
combined_df
# Out:
#            CUSTOMER         AREA ISPRIVATEPERSON        DATE  HOUR_0  HOUR_1  \
# 0        1060598736  Kvarnholmen      Commercial  2020-01-01   0.011   0.012
# 1        1060598736  Kvarnholmen      Commercial  2020-01-02   0.010   0.009
# 2        1060598736  Kvarnholmen      Commercial  2020-01-03   0.011   0.011
# 3        1060598736  Kvarnholmen      Commercial  2020-01-04   0.010   0.009
# 4        1060598736  Kvarnholmen      Commercial  2020-01-05   0.011   0.011
# ...             ...          ...             ...         ...     ...     ...
# 3612913  2411311923       Malmen     Residential  2023-12-27   0.000   0.000
# 3612914  2411311923       Malmen     Residential  2023-12-28   0.000   0.000
# 3612915  2411311923       Malmen     Residential  2023-12-29   0.000   0.000
# 3612916  2411311923       Malmen     Residential  2023-12-30   0.000   0.000
# 3612917  2411311923       Malmen     Residential  2023-12-31   0.000   0.000
#
# ...

# %%
# Count the number of rows with One_Day_Power equal to zero
zero_power_count = (combined_df['One_Day_Power'] == 0).sum()

print(f"Number of rows with One_Day_Power equal to zero: {zero_power_count}")
# Out:
# Number of rows with One_Day_Power equal to zero: 1039980
