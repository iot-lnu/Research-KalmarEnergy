# %%
import pandas as pd
filename = 'data/modified_final_df.csv'
df = pd.read_csv(filename, sep=',', index_col=0)

# %%
df.shape[0]
# Out:
# 91068432

# %%
df
# Out:
#                      DateTime    CUSTOMER         AREA ISPRIVATEPERSON  \
# 0         2020-01-01 00:00:00  1060598736  Kvarnholmen             Nej
# 1         2020-01-01 00:00:00  1060753918       Malmen             Nej
# 2         2020-01-01 00:00:00  1060753924       Malmen             Nej
# 3         2020-01-01 00:00:00  1060753932       Malmen             Nej
# 4         2020-01-01 00:00:00  1060753945       Malmen             Nej
# ...                       ...         ...          ...             ...
# 91068427  2023-12-31 23:00:00  1060619147       Malmen              Ja
# 91068428  2023-12-31 23:00:00  1060619139       Malmen             Nej
# 91068429  2023-12-31 23:00:00  1060619133       Malmen              Ja
# 91068430  2023-12-31 23:00:00  1060619347       Malmen              Ja
# 91068431  2023-12-31 23:00:00  2411372971       Malmen             Nej
#
#           Power_Consumption  One_Day_Power  One_Day_Power_NaN  \
# ...

# %% [markdown]
# # Descriptive Statistics of data: Check if all the features we want has the same count (9.106843e+07) for training model.

# %%
# !pip install tabulate

# %%
from tabulate import tabulate

# description = modified_final_df.describe(include='all')
columns_of_interest = ['DateTime','CUSTOMER','AREA','ISPRIVATEPERSON','Power_Consumption', 'Dew Point Temperature_P39', 'Relative Humidity_P6', 'Wind Speed_P4', 'Price']
description = df[columns_of_interest].describe()
print(tabulate(description, headers='keys', tablefmt='psql'))
# Out:
# +-------+-------------+---------------------+-----------------------------+------------------------+-----------------+---------------+
# |       |    CUSTOMER |   Power_Consumption |   Dew Point Temperature_P39 |   Relative Humidity_P6 |   Wind Speed_P4 |         Price |
# |-------+-------------+---------------------+-----------------------------+------------------------+-----------------+---------------|
# | count | 9.10684e+07 |         9.10684e+07 |                 9.10684e+07 |            9.10684e+07 |     9.10684e+07 |   9.10684e+07 |
# | mean  | 1.14654e+09 |         0.00278913  |                 5.1097      |           82.6636      |     3.50833     |  82.823       |
# | std   | 2.63651e+08 |         0.0238413   |                 6.49065     |           16.5593      |     2.08595     |  88.7804      |
# | min   | 1.0606e+09  |         0           |               -20.7         |           13           |     0           | -60.04        |
# ...

# %%
residential_df = df[df['ISPRIVATEPERSON'] == 'Ja']
commercial_df = df[df['ISPRIVATEPERSON'] == 'Nej']

# %%
residential_df.shape[0]
# Out:
# 60500160

# %%
commercial_df.shape[0]
# Out:
# 30568272

# %%
residential_df
# Out:
#                      DateTime    CUSTOMER         AREA ISPRIVATEPERSON  \
# 83        2020-01-01 00:00:00  1060760446  Kvarnholmen              Ja
# 85        2020-01-01 00:00:00  1060761119        Berga              Ja
# 102       2020-01-01 00:00:00  1060698888        Berga              Ja
# 117       2020-01-01 00:00:00  1060677215        Berga              Ja
# 118       2020-01-01 00:00:00  1060677619        Berga              Ja
# ...                       ...         ...          ...             ...
# 91068425  2023-12-31 23:00:00  1060619169       Malmen              Ja
# 91068426  2023-12-31 23:00:00  1060619160       Malmen              Ja
# 91068427  2023-12-31 23:00:00  1060619147       Malmen              Ja
# 91068429  2023-12-31 23:00:00  1060619133       Malmen              Ja
# 91068430  2023-12-31 23:00:00  1060619347       Malmen              Ja
#
#           Power_Consumption  One_Day_Power  One_Day_Power_NaN  \
# ...

# %%
commercial_df
# Out:
#                      DateTime    CUSTOMER         AREA ISPRIVATEPERSON  \
# 0         2020-01-01 00:00:00  1060598736  Kvarnholmen             Nej
# 1         2020-01-01 00:00:00  1060753918       Malmen             Nej
# 2         2020-01-01 00:00:00  1060753924       Malmen             Nej
# 3         2020-01-01 00:00:00  1060753932       Malmen             Nej
# 4         2020-01-01 00:00:00  1060753945       Malmen             Nej
# ...                       ...         ...          ...             ...
# 91068410  2023-12-31 23:00:00  1060619312       Malmen             Nej
# 91068411  2023-12-31 23:00:00  1060619299       Malmen             Nej
# 91068422  2023-12-31 23:00:00  1060619200       Malmen             Nej
# 91068428  2023-12-31 23:00:00  1060619139       Malmen             Nej
# 91068431  2023-12-31 23:00:00  2411372971       Malmen             Nej
#
#           Power_Consumption  One_Day_Power  One_Day_Power_NaN  \
# ...

# %%
residential_df.columns
# Out:
# Index(['DateTime', 'CUSTOMER', 'AREA', 'ISPRIVATEPERSON', 'Power_Consumption',
#        'One_Day_Power', 'One_Day_Power_NaN', 'Air Temperature 1 Min_P19',
#        'Air Temperature 2 Max_P27', 'Air Temperature 2 Min_P26',
#        'Dew Point Temperature_P39', 'Precipitation_P7', 'Relative Humidity_P6',
#        'Wind Speed_P4', 'Price'],
#       dtype='object')

# %%
commercial_df.columns
# Out:
# Index(['DateTime', 'CUSTOMER', 'AREA', 'ISPRIVATEPERSON', 'Power_Consumption',
#        'One_Day_Power', 'One_Day_Power_NaN', 'Air Temperature 1 Min_P19',
#        'Air Temperature 2 Max_P27', 'Air Temperature 2 Min_P26',
#        'Dew Point Temperature_P39', 'Precipitation_P7', 'Relative Humidity_P6',
#        'Wind Speed_P4', 'Price'],
#       dtype='object')

# %% [markdown]
# # Correlation Matrix - Commercial data
# ### Alias column names for better vizualization

# %%
correlation_matrix_commercial = commercial_df[['Power_Consumption', 'Dew Point Temperature_P39', 'Relative Humidity_P6', 'Wind Speed_P4', 'Price']].corr('pearson')
print(correlation_matrix_commercial)
# Out:
#                            Power_Consumption  Dew Point Temperature_P39  \
# Power_Consumption                   1.000000                  -0.001438
# Dew Point Temperature_P39          -0.001438                   1.000000
# Relative Humidity_P6               -0.014507                   0.100731
# Wind Speed_P4                       0.013913                  -0.049157
# Price                               0.011383                  -0.152569
#
#                            Relative Humidity_P6  Wind Speed_P4     Price
# Power_Consumption                     -0.014507       0.013913  0.011383
# Dew Point Temperature_P39              0.100731      -0.049157 -0.152569
# Relative Humidity_P6                   1.000000      -0.386922  0.083540
# Wind Speed_P4                         -0.386922       1.000000 -0.190354
# Price                                  0.083540      -0.190354  1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create a dictionary with your current column names as keys and the desired aliases as values
column_aliases = {
    'Dew Point Temperature_P39': 'Temperature',
    'Relative Humidity_P6': 'Humidity',
    'Wind Speed_P4': 'Wind Speed'
}

# Rename the columns in your correlation matrix
corr_commercial_renamed = correlation_matrix_commercial.rename(columns=column_aliases, index=column_aliases)

# Now, plot the heatmap with the renamed columns
f, ax = plt.subplots(figsize=(6, 6), dpi=300)
sns.heatmap(corr_commercial_renamed, cmap='RdBu_r', linewidths=0.1, annot=True, annot_kws={"fontsize":10}, ax=ax)
plt.xticks(rotation=30, fontsize=10)
plt.yticks(rotation=0, fontsize=10)

# Save the figure as before
plt.savefig('figures/pearson_corr_commercial_aliased.jpg', dpi=300, bbox_inches='tight', pad_inches=0.02)
plt.show()

# %% [markdown]
# # Correlation Matrix - Commercial data 2021
# ### Alias column names for better vizualization

# %%
commercial_df_2021 = pd.read_csv('data/commercial_df_2021.csv', index_col=0) # Remove the unnamed column using index_col=0 instead of the command #df = df.iloc[:, 1:]

# %%
commercial_df_2021
# Out:
#                      DateTime    CUSTOMER         AREA ISPRIVATEPERSON  \
# 6944448   2021-01-01 00:00:00  1060753805  Kvarnholmen             Nej
# 6944449   2021-01-01 00:00:00  1060766019       Malmen             Nej
# 6944451   2021-01-01 00:00:00  1060616621       Malmen             Nej
# 6944452   2021-01-01 00:00:00  1060621516       Malmen             Nej
# 6944453   2021-01-01 00:00:00  1060601163  Kvarnholmen             Nej
# ...                       ...         ...          ...             ...
# 14619619  2021-12-31 23:00:00  1060598838  Kvarnholmen             Nej
# 14619620  2021-12-31 23:00:00  1060598788  Kvarnholmen             Nej
# 14619621  2021-12-31 23:00:00  1060604204  Kvarnholmen             Nej
# 14619622  2021-12-31 23:00:00  1060599041  Kvarnholmen             Nej
# 14619623  2021-12-31 23:00:00  1060603544  Kvarnholmen             Nej
#
#           Power_Consumption  One_Day_Power  One_Day_Power_NaN  \
# ...

# %%
correlation_matrix_commercial_2021 = commercial_df_2021[['Power_Consumption', 'Dew Point Temperature_P39', 'Relative Humidity_P6', 'Wind Speed_P4', 'Price']].corr('pearson')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create a dictionary with your current column names as keys and the desired aliases as values
column_aliases = {
    'Dew Point Temperature_P39': 'Temperature',
    'Relative Humidity_P6': 'Humidity',
    'Wind Speed_P4': 'Wind Speed'
}

# Rename the columns in your correlation matrix
corr_commercial_renamed = correlation_matrix_commercial_2021.rename(columns=column_aliases, index=column_aliases)

# Now, plot the heatmap with the renamed columns
f, ax = plt.subplots(figsize=(6, 6), dpi=300)
sns.heatmap(corr_commercial_renamed, cmap='RdBu_r', linewidths=0.1, annot=True, annot_kws={"fontsize":10}, ax=ax)
plt.xticks(rotation=30, fontsize=10)
plt.yticks(rotation=0, fontsize=10)

# Save the figure as before
plt.savefig('figures/pearson_corr_commercial_aliased.jpg', dpi=300, bbox_inches='tight', pad_inches=0.02)
plt.show()

# %% [markdown]
# # Correlation Matrix - Residential data

# %%
correlation_matrix_residential = residential_df[['Power_Consumption', 'Dew Point Temperature_P39', 'Relative Humidity_P6', 'Wind Speed_P4', 'Price']].corr('pearson')
print(correlation_matrix_residential)
# Out:
#                            Power_Consumption  Dew Point Temperature_P39  \
# Power_Consumption                   1.000000                  -0.101153
# Dew Point Temperature_P39          -0.101153                   1.000000
# Relative Humidity_P6               -0.003375                   0.091779
# Wind Speed_P4                       0.023618                  -0.035399
# Price                               0.057018                  -0.315396
#
#                            Relative Humidity_P6  Wind Speed_P4     Price
# Power_Consumption                     -0.003375       0.023618  0.057018
# Dew Point Temperature_P39              0.091779      -0.035399 -0.315396
# Relative Humidity_P6                   1.000000      -0.403700  0.123167
# Wind Speed_P4                         -0.403700       1.000000 -0.193209
# Price                                  0.123167      -0.193209  1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create a dictionary with your current column names as keys and the desired aliases as values
column_aliases = {
    'Dew Point Temperature_P39': 'Temperature',
    'Relative Humidity_P6': 'Humidity',
    'Wind Speed_P4': 'Wind Speed'
}

# Rename the columns in your correlation matrix
corr_residential_renamed = correlation_matrix_residential.rename(columns=column_aliases, index=column_aliases)

# Now, plot the heatmap with the renamed columns
f, ax = plt.subplots(figsize=(6, 6), dpi=300)
sns.heatmap(corr_residential_renamed, cmap='RdBu_r', linewidths=0.1, annot=True, annot_kws={"fontsize":10}, ax=ax)
plt.xticks(rotation=30, fontsize=10)
plt.yticks(rotation=0, fontsize=10)

# Save the figure as before
plt.savefig('figures/pearson_corr_residential_aliased.jpg', dpi=300, bbox_inches='tight', pad_inches=0.02)
plt.show()

# %% [markdown]
# # Model - Commercial Data

# %%
from tabulate import tabulate

# description = modified_final_df.describe(include='all')
columns_of_interest = ['Power_Consumption', 'Dew Point Temperature_P39', 'Relative Humidity_P6', 'Wind Speed_P4', 'Price']
description = commercial_df[columns_of_interest].describe()
print(tabulate(description, headers='keys', tablefmt='psql'))
# Out:
# +-------+---------------------+-----------------------------+------------------------+-----------------+---------------+
# |       |   Power_Consumption |   Dew Point Temperature_P39 |   Relative Humidity_P6 |   Wind Speed_P4 |         Price |
# |-------+---------------------+-----------------------------+------------------------+-----------------+---------------|
# | count |         3.05683e+07 |                 3.05683e+07 |            3.05683e+07 |     3.05683e+07 |   3.05683e+07 |
# | mean  |         0.00737408  |                 5.11082     |           82.1562      |     3.57        |  80.0294      |
# | std   |         0.0407469   |                 6.47565     |           16.5817      |     2.13583     |  89.3693      |
# | min   |         0           |               -20.7         |           13           |     0           | -60.04        |
# | 25%   |         0.000343    |                 0.9         |           74           |     2           |  22.46        |
# ...

# %% [markdown]
# # Work with a part of data which we know (from vizualization) follows correct/linear pattern and there is no Spike. For example 2020.

# %%
# Convert 'DateTime' to datetime if it's not already
commercial_df['DateTime'] = pd.to_datetime(commercial_df['DateTime'])
# Filter the DataFrame for the year 2020
commercial_df_2020 = commercial_df[commercial_df['DateTime'].dt.year == 2020]
# Out:
# /var/folders/bl/02tnlb3j63n87b_hctf4mh380000gq/T/ipykernel_2311/625504919.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   commercial_df['DateTime'] = pd.to_datetime(commercial_df['DateTime'])

# %%
from tabulate import tabulate

# description = modified_final_df.describe(include='all')
columns_of_interest = ['Power_Consumption', 'Dew Point Temperature_P39', 'Relative Humidity_P6', 'Wind Speed_P4', 'Price']
description = commercial_df_2020[columns_of_interest].describe()
print(tabulate(description, headers='keys', tablefmt='psql'))
# Out:
# +-------+---------------------+-----------------------------+------------------------+-----------------+---------------+
# |       |   Power_Consumption |   Dew Point Temperature_P39 |   Relative Humidity_P6 |   Wind Speed_P4 |         Price |
# |-------+---------------------+-----------------------------+------------------------+-----------------+---------------|
# | count |         5.68219e+06 |                 5.68219e+06 |            5.68219e+06 |     5.68219e+06 |   5.68219e+06 |
# | mean  |         0.00849443  |                 5.85989     |           80.2543      |     3.89782     |  25.9794      |
# | std   |         0.0247667   |                 5.74176     |           17.3516      |     2.34232     |  20.2812      |
# | min   |         0           |               -14.1         |           19           |     0           |  -1.96        |
# | 25%   |         0.00091     |                 2           |           71           |     2           |  10.1         |
# ...

# %%
commercial_df_2020.shape[0]
# Out:
# 5682192

# %% [markdown]
# # Work with each area

# %%
# List of areas
areas = ['Kvarnholmen', 'Berga', 'Malmen', 'Stensö', 'Varvsholmen']

# Dictionary to hold DataFrames for each area
area_dfs = {}

# Loop through each area and filter the DataFrame, then store it in the dictionary
for area in areas:
    area_dfs[area] = commercial_df_2020[commercial_df_2020['AREA'] == area]

# Now you can access the DataFrame for each area by using the area name as a key
# For example, to access the DataFrame for Kvarnholmen, you would use:
kvarnholmen_df = area_dfs['Kvarnholmen']

# %%
kvarnholmen_df
# Out:
#                    DateTime    CUSTOMER         AREA ISPRIVATEPERSON  \
# 0       2020-01-01 00:00:00  1060598736  Kvarnholmen             Nej
# 16      2020-01-01 00:00:00  1060759807  Kvarnholmen             Nej
# 17      2020-01-01 00:00:00  1060759815  Kvarnholmen             Nej
# 18      2020-01-01 00:00:00  1060759845  Kvarnholmen             Nej
# 19      2020-01-01 00:00:00  1060759857  Kvarnholmen             Nej
# ...                     ...         ...          ...             ...
# 6944434 2020-12-31 23:00:00  1060766704  Kvarnholmen             Nej
# 6944436 2020-12-31 23:00:00  1060753439  Kvarnholmen             Nej
# 6944440 2020-12-31 23:00:00  1060610086  Kvarnholmen             Nej
# 6944445 2020-12-31 23:00:00  1060911201  Kvarnholmen             Nej
# 6944447 2020-12-31 23:00:00  1060610143  Kvarnholmen             Nej
#
#          Power_Consumption  One_Day_Power  One_Day_Power_NaN  \
# 0                 0.011200       0.260400                  0
# ...

# %%
kvarnholmen_df.shape[0]
# Out:
# 2780712

# %%
from tabulate import tabulate

# description = modified_final_df.describe(include='all')
columns_of_interest = ['Power_Consumption', 'Temperature', 'Humidity', 'Wind Speed', 'Price']
description = kvarnholmen_df[columns_of_interest].describe()
print(tabulate(description, headers='keys', tablefmt='psql'))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[25], line 5
#       3 # description = modified_final_df.describe(include='all')
#       4 columns_of_interest = ['Power_Consumption', 'Temperature', 'Humidity', 'Wind Speed', 'Price']
# ----> 5 description = kvarnholmen_df[columns_of_interest].describe()
#       6 print(tabulate(description, headers='keys', tablefmt='psql'))
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/frame.py:4096, in DataFrame.__getitem__(self, key)
#    4094     if is_iterator(key):
#    4095         key = list(key)
# -> 4096     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4098 # take() does not accept boolean indexers
#    4099 if getattr(indexer, "dtype", None) == bool:
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/indexes/base.py:6199, in Index._get_indexer_strict(self, key, axis_name)
# ...

# %% [markdown]
# # XGBoost model on Kvarnholmen area of year 2020

# %%
from sklearn.metrics import mean_squared_error 
import numpy as np
from sklearn.metrics import r2_score
from sklearn import metrics
import xgboost as xgb
from sklearn.model_selection import GridSearchCV
import time
from sklearn.model_selection import train_test_split
from pandas import DataFrame,Series
xtrain,xtest,ytrain,ytest = train_test_split(kvarnholmen_df[['Temperature', 'Humidity', 'Wind Speed', 'Price']].values,kvarnholmen_df['Power_Consumption'],test_size=0.25)
print("TRAIN:",xtrain.shape, "；  TEST:",xtest.shape)
print("TRAIN:",ytrain.shape, "；  TEST:",ytest.shape)
start = time.perf_counter()
cv_params = [
            {'n_estimators': [50,500,50],
             'max_depth':[1,15,1],
             'learning_rate':[0.1,0.2,0.3,0.4]}
              ]
other_params = {}

xg = xgb.XGBRegressor(**other_params)
optimized_GBM = GridSearchCV(estimator=xg, param_grid=cv_params, scoring='r2', cv=5, verbose=1, n_jobs=-1)
optimized_GBM.fit(xtrain, ytrain)
evalute_result = optimized_GBM.cv_results_['mean_test_score']
end = time.perf_counter()
runtime = end - start
print("Runtime = ", runtime)
#print('Results of each iteration:{0}'.format(evalute_result))
print('Best params：{0}'.format(optimized_GBM.best_params_))
print('Best model score:{0}'.format(optimized_GBM.best_score_))
# Out:
# TRAIN: (2085534, 4) ；  TEST: (695178, 4)
# TRAIN: (2085534,) ；  TEST: (695178,)
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# /opt/homebrew/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Runtime =  182.50921304099757
# Best params：{'learning_rate': 0.1, 'max_depth': 15, 'n_estimators': 50}
# Best model score:0.02189736600884795

# %%
def mape(y_true, y_pred):
    return np.mean(np.abs((y_pred - y_true) / y_true)) * 100
xg = xgb.XGBRegressor(learning_rate=0.1, max_delta_step=0, max_depth=1,
                      min_child_weight=3,n_estimators=500, n_jobs=-1)
xg.fit(xtrain, ytrain)
xg_pre = xg.predict(xtest)
blk_ytest_np2 = np.array(ytest)

xg_lm = mean_squared_error(blk_ytest_np2, xg_pre)
print("xg_MSE:", xg_lm)
xg_lrm = np.sqrt(xg_lm)
print("xg_RMSE:", xg_lrm)
xg_mae = metrics.mean_absolute_error(blk_ytest_np2, xg_pre)
print("xg_MAE:", xg_mae)
xg_mape = mape(blk_ytest_np2, xg_pre)
print("xg_MAPE:", xg_mape)
xg_r2 = r2_score(blk_ytest_np2, xg_pre)
print("xg_score2:",xg_r2)
# Out:
# xg_MSE: 0.0001824542514478764
# xg_RMSE: 0.013507562750099532
# xg_MAE: 0.007918649373469517
# xg_MAPE: inf
# xg_score2: 0.012641799146391297
# /var/folders/bl/02tnlb3j63n87b_hctf4mh380000gq/T/ipykernel_20819/589237842.py:2: RuntimeWarning: divide by zero encountered in divide
#   return np.mean(np.abs((y_pred - y_true) / y_true)) * 100

# %% [markdown]
# # I wanna do Kvarnholmen of year 2021, but with daily data (average of power consumption (all records of a specific day divided by number of them), daily price, daily temperature, daily humidity, daily wind speed)

# %%
# Convert 'DateTime' to datetime if it's not already
commercial_df['DateTime'] = pd.to_datetime(commercial_df['DateTime'])
# Filter the DataFrame for the year 2021
commercial_df_2021 = commercial_df[commercial_df['DateTime'].dt.year == 2021]
# Out:
# /var/folders/bl/02tnlb3j63n87b_hctf4mh380000gq/T/ipykernel_34624/2042654296.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   commercial_df['DateTime'] = pd.to_datetime(commercial_df['DateTime'])

# %%
import pandas as pd
import pandas as pd
from sktime.forecasting.fbprophet import Prophet
from sktime.forecasting.base import ForecastingHorizon
from sktime.performance_metrics.forecasting import mean_absolute_percentage_error
from sktime.split import temporal_train_test_split
from sktime.utils.plotting import plot_series
from sktime.forecasting.arima import AutoARIMA

# %%
# Load csv file
commercial_df_2021 = pd.read_csv('data/yearlyData/commercial_df_2021.csv', index_col=0)

# %%
from tabulate import tabulate

# description = modified_final_df.describe(include='all')
columns_of_interest = ['Power_Consumption', 'Dew Point Temperature_P39', 'Relative Humidity_P6', 'Wind Speed_P4', 'Price']
description = commercial_df_2021[columns_of_interest].describe()
print(tabulate(description, headers='keys', tablefmt='psql'))
# Out:
# +-------+---------------------+-----------------------------+------------------------+-----------------+---------------+
# |       |   Power_Consumption |   Dew Point Temperature_P39 |   Relative Humidity_P6 |   Wind Speed_P4 |         Price |
# |-------+---------------------+-----------------------------+------------------------+-----------------+---------------|
# | count |         5.86308e+06 |                 5.86308e+06 |            5.86308e+06 |     5.86308e+06 |   5.86308e+06 |
# | mean  |         0.00867756  |                 4.88422     |           81.9346      |     3.44733     |  80.4441      |
# | std   |         0.0273849   |                 7.5381      |           16.588       |     2.0197      |  63.7735      |
# | min   |         0           |               -20.7         |           24           |     0           |  -1.97        |
# | 25%   |         0.000732    |                -0.2         |           73           |     2           |  43.91        |
# ...

# %%
commercial_df_2021.shape[0]
# Out:
# 5863080

# %%
# List of areas
areas = ['Kvarnholmen', 'Berga', 'Malmen', 'Stensö', 'Varvsholmen']

# Dictionary to hold DataFrames for each area
area_dfs = {}

# Loop through each area and filter the DataFrame, then store it in the dictionary
for area in areas:
    area_dfs[area] = commercial_df_2021[commercial_df_2021['AREA'] == area]

# Now you can access the DataFrame for each area by using the area name as a key
# For example, to access the DataFrame for Kvarnholmen, you would use:
kvarnholmen_df = area_dfs['Kvarnholmen']

# %%
kvarnholmen_df
# Out:
#                    DateTime    CUSTOMER         AREA ISPRIVATEPERSON  \
# 0       2020-01-01 00:00:00  1060598736  Kvarnholmen             Nej
# 16      2020-01-01 00:00:00  1060759807  Kvarnholmen             Nej
# 17      2020-01-01 00:00:00  1060759815  Kvarnholmen             Nej
# 18      2020-01-01 00:00:00  1060759845  Kvarnholmen             Nej
# 19      2020-01-01 00:00:00  1060759857  Kvarnholmen             Nej
# ...                     ...         ...          ...             ...
# 6944434 2020-12-31 23:00:00  1060766704  Kvarnholmen             Nej
# 6944436 2020-12-31 23:00:00  1060753439  Kvarnholmen             Nej
# 6944440 2020-12-31 23:00:00  1060610086  Kvarnholmen             Nej
# 6944445 2020-12-31 23:00:00  1060911201  Kvarnholmen             Nej
# 6944447 2020-12-31 23:00:00  1060610143  Kvarnholmen             Nej
#
#          Power_Consumption  One_Day_Power  One_Day_Power_NaN  \
# 0                 0.011200       0.260400                  0
# ...

# %%
from tabulate import tabulate

# description = modified_final_df.describe(include='all')
columns_of_interest = ['Power_Consumption', 'Dew Point Temperature_P39', 'Relative Humidity_P6', 'Wind Speed_P4', 'Price']
description = kvarnholmen_df[columns_of_interest].describe()
print(tabulate(description, headers='keys', tablefmt='psql'))
# Out:
# +-------+---------------------+-----------------------------+------------------------+-----------------+---------------+
# |       |   Power_Consumption |   Dew Point Temperature_P39 |   Relative Humidity_P6 |   Wind Speed_P4 |         Price |
# |-------+---------------------+-----------------------------+------------------------+-----------------+---------------|
# | count |         2.78071e+06 |                 2.78071e+06 |            2.78071e+06 |     2.78071e+06 |   2.78071e+06 |
# | mean  |         0.00767564  |                 5.86294     |           80.2284      |     3.8989      |  25.9443      |
# | std   |         0.0135963   |                 5.74562     |           17.3594      |     2.34377     |  20.2399      |
# | min   |         0           |               -14.1         |           19           |     0           |  -1.96        |
# | 25%   |         0.000886    |                 2           |           71           |     2           |  10.09        |
# ...

# %%
# Load the data
residential_df_2021 = pd.read_csv('data/yearlyData/residential_df_2021.csv', index_col=0)

# %%
# List of areas
areas = ['Kvarnholmen', 'Berga', 'Malmen', 'Stensö', 'Varvsholmen']

# Dictionary to hold DataFrames for each area
area_dfs = {}

# Loop through each area and filter the DataFrame, then store it in the dictionary
for area in areas:
    area_dfs[area] = residential_df_2021[residential_df_2021['AREA'] == area]

# Now you can access the DataFrame for each area by using the area name as a key
# For example, to access the DataFrame for Kvarnholmen, you would use:
kvarnholmen_df_r = area_dfs['Kvarnholmen']
berga_df_r = area_dfs['Berga']
stensö_df_r = area_dfs['Stensö']
varvsholmen_df_r = area_dfs['Varvsholmen']
malmen_df_r = area_dfs['Malmen']

# %% [markdown]
# # from this part until Xi code for XGBoost, is for ARIMA modeling

# %%
kvarnholmen_df.dtypes
# Out:
# DateTime                      object
# CUSTOMER                       int64
# AREA                          object
# ISPRIVATEPERSON               object
# Power_Consumption            float64
# One_Day_Power                float64
# One_Day_Power_NaN              int64
# Air Temperature 1 Min_P19    float64
# Air Temperature 2 Max_P27    float64
# Air Temperature 2 Min_P26    float64
# Dew Point Temperature_P39    float64
# Precipitation_P7             float64
# Relative Humidity_P6         float64
# Wind Speed_P4                float64
# Price                        float64
# dtype: object

# %% [markdown]
# ### This is importatnt: if 'DateTime' is not in datetime format, you will need to convert it before setting it as the index:

# %%
# Convert 'DateTime' to datetime if it's not already
kvarnholmen_df['DateTime'] = pd.to_datetime(kvarnholmen_df['DateTime'])
# Out:
# /var/folders/bl/02tnlb3j63n87b_hctf4mh380000gq/T/ipykernel_61923/525633304.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kvarnholmen_df['DateTime'] = pd.to_datetime(kvarnholmen_df['DateTime'])

# %%
kvarnholmen_df.dtypes
# Out:
# DateTime                     datetime64[ns]
# CUSTOMER                              int64
# AREA                                 object
# ISPRIVATEPERSON                      object
# Power_Consumption                   float64
# One_Day_Power                       float64
# One_Day_Power_NaN                     int64
# Air Temperature 1 Min_P19           float64
# Air Temperature 2 Max_P27           float64
# Air Temperature 2 Min_P26           float64
# Dew Point Temperature_P39           float64
# Precipitation_P7                    float64
# Relative Humidity_P6                float64
# Wind Speed_P4                       float64
# Price                               float64
# dtype: object

# %%
# Set 'DateTime' as index
kvarnholmen_df.set_index('DateTime', inplace=True)

# %%
kvarnholmen_df
# Out:
#                        CUSTOMER         AREA ISPRIVATEPERSON  \
# DateTime
# 2021-01-01 00:00:00  1060753805  Kvarnholmen             Nej
# 2021-01-01 00:00:00  1060601163  Kvarnholmen             Nej
# 2021-01-01 00:00:00  1060603544  Kvarnholmen             Nej
# 2021-01-01 00:00:00  1060599593  Kvarnholmen             Nej
# 2021-01-01 00:00:00  1060606675  Kvarnholmen             Nej
# ...                         ...          ...             ...
# 2021-12-31 23:00:00  1060598838  Kvarnholmen             Nej
# 2021-12-31 23:00:00  1060598788  Kvarnholmen             Nej
# 2021-12-31 23:00:00  1060604204  Kvarnholmen             Nej
# 2021-12-31 23:00:00  1060599041  Kvarnholmen             Nej
# 2021-12-31 23:00:00  1060603544  Kvarnholmen             Nej
#
#                      Power_Consumption  One_Day_Power  One_Day_Power_NaN  \
# DateTime
# 2021-01-01 00:00:00           0.001000       0.023940                  0
# ...

# %%
import pandas as pd
import os
import matplotlib.pyplot as plt

# Create a separate column for date without time
kvarnholmen_df['date'] = pd.to_datetime(kvarnholmen_df.index.date)

# Count the number of unique days and weeks.
num_days = kvarnholmen_df['date'].nunique()
num_weeks = kvarnholmen_df['date'].dt.to_period('W').nunique()

print("Number of Unique Days:", num_days)
print("Number of Unique Weeks:", num_weeks)

# Visualize number of data points per day
kvarnholmen_df['date'].value_counts().sort_index().plot(kind='bar', figsize=(12, 6))
plt.title('Number of data points per Day')
plt.xlabel('Date')
plt.ylabel('Count')
plt.show()

# Visualize number of data points per week
kvarnholmen_df['date'].dt.to_period('W').value_counts().sort_index().plot(kind='bar', figsize=(12, 6))
plt.title('Number of data points per Week')
plt.xlabel('Week')
plt.ylabel('Count')
kvarnholmen_df
# Out:
# /var/folders/bl/02tnlb3j63n87b_hctf4mh380000gq/T/ipykernel_61923/1090170642.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kvarnholmen_df['date'] = pd.to_datetime(kvarnholmen_df.index.date)
# Number of Unique Days: 365
# Number of Unique Weeks: 53
#                        CUSTOMER         AREA ISPRIVATEPERSON  \
# DateTime
# 2021-01-01 00:00:00  1060753805  Kvarnholmen             Nej
# 2021-01-01 00:00:00  1060601163  Kvarnholmen             Nej
# 2021-01-01 00:00:00  1060603544  Kvarnholmen             Nej
# 2021-01-01 00:00:00  1060599593  Kvarnholmen             Nej
# 2021-01-01 00:00:00  1060606675  Kvarnholmen             Nej
# ...                         ...          ...             ...
# ...

# %% [markdown]
# ###### When you're building a forecasting model, evaluating its performance over a single forecast horizon (such as one hour ahead) may not provide enough information about how well the model will perform in real-world scenarios. It's often more informative to evaluate the model over multiple future time points to see how it performs over time. For example, let's say you have hourly data, and you’re interested in forecasting the power consumption for the next hour. Technically, you could set the test size to 1 when splitting your dataset, which means you'd be testing the model's prediction for just one hour ahead. However, this doesn't tell you much about the model's performance beyond that specific hour. Instead, you might choose to test the model's predictions for the next 24 hours. This way, you can see how well the model does not just one hour ahead, but two hours ahead, three hours ahead, and so on, up to 24 hours ahead. This gives you a much clearer picture of how the model performs over a range of future times, which is likely to be more representative of how the model will perform in practice.

# %%
import os
# Assume kvarnholmen_df has columns 'DateTime', 'CUSTOMER', and 'Power_Consumption'
# Convert 'DateTime' to pandas datetime if it's not already
#kvarnholmen_df['DateTime'] = pd.to_datetime(kvarnholmen_df['DateTime'])
#kvarnholmen_df.set_index('DateTime', inplace=True)

# Select data for a single customer
customer_id = 1060753805  # Replace with actual customer ID
customer_data = kvarnholmen_df[kvarnholmen_df['CUSTOMER'] == customer_id]['Power_Consumption']  # y is your time series data with hourly readings, so here, y=customer_data which is the dataframe that includes power_consumption of customer 1060753805

# Ensure 'forecasts' directory exists
output_dir = "forecasts"
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Define a function to perform the forecasting steps
def forecast_and_evaluate(data, frequency):
    # Resample data if frequency is not 'H' (hourly)  (your data is hourly by default)
    if frequency == 'H':  # Hourly
      sp = 24  # Assuming daily seasonality for hourly data (If the original data is hourly and you're expecting daily seasonality, you would set sp=24 for the hourly frequency.)
    elif frequency == 'D':  # Daily
      data = data.resample('D').sum()
      sp = 7  # Assuming weekly seasonality for daily data
    elif frequency == 'W':  # Weekly
      data = data.resample('W').sum()
      sp = None  # Seasonality might not be clear for weekly data
    elif frequency == 'M':  # Monthly
      data = data.resample('M').sum()
      sp = None  # Seasonality might not be clear for monthly data
    
    # You are interested in forecasting the next hour, but for evaluation, you want to see how the model performs over the next 24 hours
    test_size = 24  # 24 hours
    
    # Split the data
    y_train, y_test = temporal_train_test_split(data, test_size=test_size) # split data into train and test: total: 8760 (365*24) train: 8736 test:24
     
    # Define the forecasting horizon to be the next 24 hours
    fh = ForecastingHorizon(y_test.index, is_relative=False)   # fh=24 hours (it is for future, i.e., the test_size determines how many future time points you want to withhold from your training data to use for evaluation. The ForecastingHorizon (fh) is then used to specify which time points in the future you want to predict for.)
    
    # Train the model
    model = AutoARIMA(sp=sp, suppress_warnings=True)  # Seasonal periodicity (sp) can vary based on (input data) frequency
    
    # Now you can fit a forecasting model on y_train and evaluate its predictions using y_test, which contains the actual values for the next 24 hours.
    model.fit(y_train)
    
    # Forecast
    y_pred = model.predict(fh)
    
    # Evaluate
    mape = mean_absolute_percentage_error(y_pred, y_test)
    print(f'MAPE for frequency {frequency}: {mape}')
    
    # Plot
    plot_series(y_train, y_test, y_pred, labels=["y_train", "y_test", "y_pred"])
    plt.title(f"Forecasting at {frequency} frequency for customer {customer_id}")
    
    # Save the plot to the 'forecasts' directory
    plt.savefig(f'{output_dir}/customer_{customer_id}_forecast_{frequency}.png')
    
    # Show the plot
    plt.show()

# Forecast and evaluate for different frequencies (this means you make the input data hourly (if it is recorded in minute), daily, weekly, monthly)
for frequency in ['H', 'D', 'W', 'M']:
    print(f"Forecasting at {frequency} frequency for customer {customer_id}:")
    forecast_and_evaluate(customer_data.copy(), frequency)
# Out:
# Forecasting at H frequency for customer 1060753805:
# MAPE for frequency H: 0.14848990595433323
# Forecasting at D frequency for customer 1060753805:
# MAPE for frequency D: 0.0567956523803613
# Forecasting at W frequency for customer 1060753805:
# MAPE for frequency W: 0.0503003388554338
# Forecasting at M frequency for customer 1060753805:
# /var/folders/bl/02tnlb3j63n87b_hctf4mh380000gq/T/ipykernel_61923/3194756077.py:28: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   data = data.resample('M').sum()
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 66
#      64 for frequency in ['H', 'D', 'W', 'M']:
#      65     print(f"Forecasting at {frequency} frequency for customer {customer_id}:")
# ---> 66     forecast_and_evaluate(customer_data.copy(), frequency)
#
# ...

# %% [markdown]
# # Xi code for XGBoost

# %%
from sklearn.metrics import mean_squared_error 
import numpy as np
from sklearn.metrics import r2_score
from sklearn import metrics
import xgboost as xgb
from sklearn.model_selection import GridSearchCV
import time
from sklearn.model_selection import train_test_split
from pandas import DataFrame,Series
xtrain,xtest,ytrain,ytest = train_test_split(kvarnholmen_df[['Average Temperature', 'Average Price']].values,kvarnholmen_df['Average Power Consumption'],test_size=0.25)
print("TRAIN:",xtrain.shape, "；  TEST:",xtest.shape)
print("TRAIN:",ytrain.shape, "；  TEST:",ytest.shape)
start = time.perf_counter()
cv_params = [
            {'n_estimators': [50,500,50],
             'max_depth':[1,15,1],
             'learning_rate':[0.1,0.2,0.3,0.4]}
              ]
other_params = {}

xg = xgb.XGBRegressor(**other_params)
optimized_GBM = GridSearchCV(estimator=xg, param_grid=cv_params, scoring='r2', cv=5, verbose=1, n_jobs=-1)
optimized_GBM.fit(xtrain, ytrain)
evalute_result = optimized_GBM.cv_results_['mean_test_score']
end = time.perf_counter()
runtime = end - start
print("Runtime = ", runtime)
#print('Results of each iteration:{0}'.format(evalute_result))
print('Best params：{0}'.format(optimized_GBM.best_params_))
print('Best model score:{0}'.format(optimized_GBM.best_score_))
# Out:
# TRAIN: (273, 4) ；  TEST: (92, 4)
# TRAIN: (273,) ；  TEST: (92,)
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# Runtime =  0.5944887500008917
# Best params：{'learning_rate': 0.4, 'max_depth': 15, 'n_estimators': 50}
# Best model score:0.45295497625285197

# %%
def mape(y_true, y_pred):
    return np.mean(np.abs((y_pred - y_true) / y_true)) * 100
xg = xgb.XGBRegressor(learning_rate=0.1, max_delta_step=0, max_depth=1,
                      min_child_weight=3,n_estimators=500, n_jobs=-1)
xg.fit(xtrain, ytrain)
xg_pre = xg.predict(xtest)
blk_ytest_np2 = np.array(ytest)

xg_lm = mean_squared_error(blk_ytest_np2, xg_pre)
print("xg_MSE:", xg_lm)
xg_lrm = np.sqrt(xg_lm)
print("xg_RMSE:", xg_lrm)
xg_mae = metrics.mean_absolute_error(blk_ytest_np2, xg_pre)
print("xg_MAE:", xg_mae)
xg_mape = mape(blk_ytest_np2, xg_pre)
print("xg_MAPE:", xg_mape)
xg_r2 = r2_score(blk_ytest_np2, xg_pre)
print("xg_score2:",xg_r2)
# Out:
# xg_MSE: 0.00029701550164436296
# xg_RMSE: 0.017234137682064714
# xg_MAE: 0.013360145137839457
# xg_MAPE: 7.366270962405378
# xg_score2: 0.25042006252474425

# %% [markdown]
# # Xi code for XGBoost (consdier only price based on the Feature Attribute of AutoML from VertexAI) -> daily average price and total daily power consumption

# %%
# Convert 'DateTime' to datetime if it's not already
kvarnholmen_df['DateTime'] = pd.to_datetime(kvarnholmen_df['DateTime'])
# Set 'DateTime' as index
kvarnholmen_df.set_index('DateTime', inplace=True)
# Out:
# /var/folders/bl/02tnlb3j63n87b_hctf4mh380000gq/T/ipykernel_34624/1741723862.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kvarnholmen_df['DateTime'] = pd.to_datetime(kvarnholmen_df['DateTime'])

# %%
kvarnholmen_df
# Out:
#                        CUSTOMER         AREA ISPRIVATEPERSON  \
# DateTime
# 2021-01-01 00:00:00  1060753805  Kvarnholmen             Nej
# 2021-01-01 00:00:00  1060601163  Kvarnholmen             Nej
# 2021-01-01 00:00:00  1060603544  Kvarnholmen             Nej
# 2021-01-01 00:00:00  1060599593  Kvarnholmen             Nej
# 2021-01-01 00:00:00  1060606675  Kvarnholmen             Nej
# ...                         ...          ...             ...
# 2021-12-31 23:00:00  1060598838  Kvarnholmen             Nej
# 2021-12-31 23:00:00  1060598788  Kvarnholmen             Nej
# 2021-12-31 23:00:00  1060604204  Kvarnholmen             Nej
# 2021-12-31 23:00:00  1060599041  Kvarnholmen             Nej
# 2021-12-31 23:00:00  1060603544  Kvarnholmen             Nej
#
#                      Power_Consumption  One_Day_Power  One_Day_Power_NaN  \
# DateTime
# 2021-01-01 00:00:00           0.001000       0.023940                  0
# ...

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import xgboost as xgb
from sklearn.model_selection import GridSearchCV
import time
from sklearn.metrics import r2_score

# Resample to daily data
daily_data = kvarnholmen_df.resample('D').agg({'Price':'mean', 'Power_Consumption':'sum'})

# Feature Engineering: Create new features based on the 'DateTime' index
daily_data['DayOfWeek'] = daily_data.index.dayofweek
daily_data['Month'] = daily_data.index.month

# Include these new features in your training and testing sets
X = daily_data[['Price', 'DayOfWeek', 'Month']]
y = daily_data['Power_Consumption']

# Split the resampled data into features and target
X_train, X_test, y_train, y_test = train_test_split(
    daily_data[['Price']],  # Features (2D array)
    daily_data['Power_Consumption'],  # Target (1D array)
    test_size=0.25, 
    random_state=42
)

# Start timer for runtime calculation
start = time.perf_counter()

# Define the parameter grid for the GridSearchCV
# Hyperparameter Tuning: Expand the search with a wider range of values
cv_params = {
    'n_estimators': [100, 250, 500, 750, 1000],
    'max_depth': [3, 5, 7, 9],
    'learning_rate': [0.01, 0.05, 0.1, 0.2],
    'subsample': [0.6, 0.7, 0.8, 0.9],
    'colsample_bytree': [0.6, 0.7, 0.8, 0.9],
}

# Initialize the XGBRegressor and GridSearchCV objects
xg = xgb.XGBRegressor()
optimized_GBM = GridSearchCV(
    estimator=xg, 
    param_grid=cv_params, 
    scoring='r2', 
    cv=5, 
    verbose=1, 
    n_jobs=-1
)

# Fit the GridSearchCV object to the training data
optimized_GBM.fit(X_train, y_train)

# End timer for runtime calculation
end = time.perf_counter()
runtime = end - start

# Output the results
print("Runtime = ", runtime)
print('Best params：{0}'.format(optimized_GBM.best_params_))
print('Best model score:{0}'.format(optimized_GBM.best_score_))

# Predict and evaluate the model using the test data (optional)
predictions = optimized_GBM.predict(X_test)
r2 = r2_score(y_test, predictions)
print('Test R^2 score:', r2)
# Out:
# Fitting 5 folds for each of 1280 candidates, totalling 6400 fits
# Runtime =  75.7152962909986
# Best params：{'colsample_bytree': 0.6, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 250, 'subsample': 0.6}
# Best model score:0.26122429389885876
# Test R^2 score: 0.23439302158467956

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import numpy as np
import xgboost as xgb

# MAPE function
def mape(y_true, y_pred): 
    return np.mean(np.abs((y_pred - y_true) / y_true)) * 100

# Initialize XGBoost regressor with specified parameters
xg = xgb.XGBRegressor(learning_rate=0.1, max_delta_step=0, max_depth=1,
                      min_child_weight=3, n_estimators=500, n_jobs=-1)

# Fit the model to our training data
xg.fit(X_train, y_train)

# Predict the target on the test dataset
xg_pre = xg.predict(X_test)

# Calculate evaluation metrics
xg_mse = mean_squared_error(y_test, xg_pre)
xg_rmse = np.sqrt(xg_mse)
xg_mae = mean_absolute_error(y_test, xg_pre)
xg_mape = mape(y_test, xg_pre)
xg_r2 = r2_score(y_test, xg_pre)

# Print the evaluation metrics
print("xg_MSE:", xg_mse)
print("xg_RMSE:", xg_rmse)
print("xg_MAE:", xg_mae)
print("xg_MAPE:", xg_mape)
print("xg_score2:", xg_r2)
# Out:
# xg_MSE: 28.73805727414324
# xg_RMSE: 5.360788866775415
# xg_MAE: 4.133558244052634
# xg_MAPE: 7.118596597260571
# xg_score2: 0.26864008472699363

# %% [markdown]
# # Do it for other areas as well

# %%
berga_df = area_dfs['Berga']

# %%
berga_df
# Out:
#                      DateTime    CUSTOMER   AREA ISPRIVATEPERSON  \
# 6944457   2021-01-01 00:00:00  1060703101  Berga             Nej
# 6944463   2021-01-01 00:00:00  1060661755  Berga             Nej
# 6944466   2021-01-01 00:00:00  1060659910  Berga             Nej
# 6944472   2021-01-01 00:00:00  1126520437  Berga             Nej
# 6944480   2021-01-01 00:00:00  1060698304  Berga             Nej
# ...                       ...         ...    ...             ...
# 14619462  2021-12-31 23:00:00  1060702786  Berga             Nej
# 14619464  2021-12-31 23:00:00  1636771395  Berga             Nej
# 14619467  2021-12-31 23:00:00  1060703094  Berga             Nej
# 14619469  2021-12-31 23:00:00  1060703101  Berga             Nej
# 14619471  2021-12-31 23:00:00  1060703113  Berga             Nej
#
#           Power_Consumption  One_Day_Power  One_Day_Power_NaN  \
# 6944457            0.001500       0.045900                  0
# ...

# %%
# Convert 'DateTime' to datetime if it's not already
berga_df['DateTime'] = pd.to_datetime(berga_df['DateTime'])
# Set 'DateTime' as index
berga_df.set_index('DateTime', inplace=True)
# Out:
# /var/folders/bl/02tnlb3j63n87b_hctf4mh380000gq/T/ipykernel_34624/755931866.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   berga_df['DateTime'] = pd.to_datetime(berga_df['DateTime'])

# %%
berga_df
# Out:
#                        CUSTOMER   AREA ISPRIVATEPERSON  Power_Consumption  \
# DateTime
# 2021-01-01 00:00:00  1060703101  Berga             Nej           0.001500
# 2021-01-01 00:00:00  1060661755  Berga             Nej           0.003060
# 2021-01-01 00:00:00  1060659910  Berga             Nej           0.001205
# 2021-01-01 00:00:00  1126520437  Berga             Nej           0.007800
# 2021-01-01 00:00:00  1060698304  Berga             Nej           0.011000
# ...                         ...    ...             ...                ...
# 2021-12-31 23:00:00  1060702786  Berga             Nej           0.001251
# 2021-12-31 23:00:00  1636771395  Berga             Nej           0.002328
# 2021-12-31 23:00:00  1060703094  Berga             Nej           0.001893
# 2021-12-31 23:00:00  1060703101  Berga             Nej           0.001311
# 2021-12-31 23:00:00  1060703113  Berga             Nej           0.011696
#
#                      One_Day_Power  One_Day_Power_NaN  \
# DateTime
# ...

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import xgboost as xgb
from sklearn.model_selection import GridSearchCV
import time
from sklearn.metrics import r2_score
from sklearn.preprocessing import StandardScaler

# Resample to daily data
daily_data = berga_df.resample('D').agg({'Price':'mean', 'Power_Consumption':'mean'})

X = daily_data['Price']

# Feature Engineering: Create new features based on the 'DateTime' index
#daily_data['DayOfWeek'] = daily_data.index.dayofweek
#daily_data['Month'] = daily_data.index.month

# Include these new features in your training and testing sets
#X = daily_data[['Price', 'DayOfWeek', 'Month']]
y = daily_data['Power_Consumption']

# Split the resampled data into features and target
X_train, X_test, y_train, y_test = train_test_split(
    daily_data[['Price']],  # Features (2D array)
    daily_data['Power_Consumption'],  # Target (1D array)
    test_size=0.25, 
    random_state=42
)


#Normalize the feature data (Scaling the data)
scaler = StandardScaler()
# Fit the scaler on the training data and transform both training and testing data
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)


# Start timer for runtime calculation
start = time.perf_counter()

# Define the parameter grid for the GridSearchCV
# Hyperparameter Tuning: Expand the search with a wider range of values
cv_params = {
    'n_estimators': [50, 100, 250, 500, 750, 1000],
    'max_depth': [3, 5, 7, 9],
    'learning_rate': [0.01, 0.05, 0.1, 0.2],
    'subsample': [0.6, 0.7, 0.8, 0.9],
    'colsample_bytree': [0.6, 0.7, 0.8, 0.9],
}

# Initialize the XGBRegressor and GridSearchCV objects
xg = xgb.XGBRegressor()
optimized_GBM = GridSearchCV(
    estimator=xg, 
    param_grid=cv_params, 
    scoring='r2', 
    cv=5, 
    verbose=1, 
    n_jobs=-1
)

# Fit the GridSearchCV object to the training data
optimized_GBM.fit(X_train, y_train)

# End timer for runtime calculation
end = time.perf_counter()
runtime = end - start

# Output the results
print("Runtime = ", runtime)
print('Best params：{0}'.format(optimized_GBM.best_params_))
print('Best model score:{0}'.format(optimized_GBM.best_score_))

# Predict and evaluate the model using the test data (optional)
predictions = optimized_GBM.predict(X_test)
r2 = r2_score(y_test, predictions)
print('Test R^2 score:', r2)
# Out:
# Fitting 5 folds for each of 1536 candidates, totalling 7680 fits
# Runtime =  27.459203916998376
# Best params：{'colsample_bytree': 0.6, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 250, 'subsample': 0.7}
# Best model score:0.07421631172646818
# Test R^2 score: 0.05370490610875167

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import numpy as np
import xgboost as xgb

# MAPE function
def mape(y_true, y_pred): 
    return np.mean(np.abs((y_pred - y_true) / y_true)) * 100

# Initialize XGBoost regressor with specified parameters
xg = xgb.XGBRegressor(learning_rate=0.1, max_delta_step=0, max_depth=1,
                      min_child_weight=3, n_estimators=500, n_jobs=-1)

# Fit the model to our training data
xg.fit(X_train, y_train)

# Predict the target on the test dataset
xg_pre = xg.predict(X_test)

# Calculate evaluation metrics
xg_mse = mean_squared_error(y_test, xg_pre)
xg_rmse = np.sqrt(xg_mse)
xg_mae = mean_absolute_error(y_test, xg_pre)
xg_mape = mape(y_test, xg_pre)
xg_r2 = r2_score(y_test, xg_pre)

# Print the evaluation metrics
print("xg_MSE:", xg_mse)
print("xg_RMSE:", xg_rmse)
print("xg_MAE:", xg_mae)
print("xg_MAPE:", xg_mape)
print("xg_score2:", xg_r2)
# Out:
# xg_MSE: 2.952405493245941
# xg_RMSE: 1.7182565271943364
# xg_MAE: 1.2494388809142134
# xg_MAPE: 10.22372142244879
# xg_score2: 0.061568642681112284

# %% [markdown]
# # Stensö

# %%
stensö_df = area_dfs['Stensö']

# %%
stensö_df
# Out:
#                      DateTime    CUSTOMER    AREA ISPRIVATEPERSON  \
# 6944459   2021-01-01 00:00:00  1060736623  Stensö             Nej
# 6944468   2021-01-01 00:00:00  1661186603  Stensö             Nej
# 6944485   2021-01-01 00:00:00  1060909074  Stensö             Nej
# 6944527   2021-01-01 00:00:00  1060753734  Stensö             Nej
# 6944538   2021-01-01 00:00:00  1060743147  Stensö             Nej
# ...                       ...         ...     ...             ...
# 14619340  2021-12-31 23:00:00  1077835541  Stensö             Nej
# 14619348  2021-12-31 23:00:00  1481044661  Stensö             Nej
# 14619349  2021-12-31 23:00:00  1481044665  Stensö             Nej
# 14619433  2021-12-31 23:00:00  1534848817  Stensö             Nej
# 14619463  2021-12-31 23:00:00  1661186603  Stensö             Nej
#
#           Power_Consumption  One_Day_Power  One_Day_Power_NaN  \
# 6944459            0.003844       0.071319                  0
# ...

# %%
# Convert 'DateTime' to datetime if it's not already
stensö_df['DateTime'] = pd.to_datetime(stensö_df['DateTime'])
# Set 'DateTime' as index
stensö_df.set_index('DateTime', inplace=True)
# Out:
# /var/folders/bl/02tnlb3j63n87b_hctf4mh380000gq/T/ipykernel_34624/879630385.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stensö_df['DateTime'] = pd.to_datetime(stensö_df['DateTime'])

# %%
stensö_df
# Out:
#                        CUSTOMER    AREA ISPRIVATEPERSON  Power_Consumption  \
# DateTime
# 2021-01-01 00:00:00  1060736623  Stensö             Nej           0.003844
# 2021-01-01 00:00:00  1661186603  Stensö             Nej           0.000892
# 2021-01-01 00:00:00  1060909074  Stensö             Nej           0.042000
# 2021-01-01 00:00:00  1060753734  Stensö             Nej           0.001600
# 2021-01-01 00:00:00  1060743147  Stensö             Nej           0.007600
# ...                         ...     ...             ...                ...
# 2021-12-31 23:00:00  1077835541  Stensö             Nej           0.001690
# 2021-12-31 23:00:00  1481044661  Stensö             Nej           0.001782
# 2021-12-31 23:00:00  1481044665  Stensö             Nej           0.002004
# 2021-12-31 23:00:00  1534848817  Stensö             Nej           0.005260
# 2021-12-31 23:00:00  1661186603  Stensö             Nej           0.003633
#
#                      One_Day_Power  One_Day_Power_NaN  \
# ...

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import xgboost as xgb
from sklearn.model_selection import GridSearchCV
import time
from sklearn.metrics import r2_score

# Resample to daily data
daily_data = stensö_df.resample('D').agg({'Price':'mean', 'Power_Consumption':'mean'})

# Feature Engineering: Create new features based on the 'DateTime' index
daily_data['DayOfWeek'] = daily_data.index.dayofweek
daily_data['Month'] = daily_data.index.month

# Include these new features in your training and testing sets
X = daily_data[['Price', 'DayOfWeek', 'Month']]
y = daily_data['Power_Consumption']

# Split the resampled data into features and target
X_train, X_test, y_train, y_test = train_test_split(
    daily_data[['Price']],  # Features (2D array)
    daily_data['Power_Consumption'],  # Target (1D array)
    test_size=0.25, 
    random_state=42
)

# Start timer for runtime calculation
start = time.perf_counter()

# Define the parameter grid for the GridSearchCV
# Hyperparameter Tuning: Expand the search with a wider range of values
cv_params = {
    'n_estimators': [100, 250, 500, 750, 1000],
    'max_depth': [3, 5, 7, 9],
    'learning_rate': [0.01, 0.05, 0.1, 0.2],
    'subsample': [0.6, 0.7, 0.8, 0.9],
    'colsample_bytree': [0.6, 0.7, 0.8, 0.9],
}

# Initialize the XGBRegressor and GridSearchCV objects
xg = xgb.XGBRegressor()
optimized_GBM = GridSearchCV(
    estimator=xg, 
    param_grid=cv_params, 
    scoring='r2', 
    cv=5, 
    verbose=1, 
    n_jobs=-1
)

# Fit the GridSearchCV object to the training data
optimized_GBM.fit(X_train, y_train)

# End timer for runtime calculation
end = time.perf_counter()
runtime = end - start

# Output the results
print("Runtime = ", runtime)
print('Best params：{0}'.format(optimized_GBM.best_params_))
print('Best model score:{0}'.format(optimized_GBM.best_score_))

# Predict and evaluate the model using the test data (optional)
predictions = optimized_GBM.predict(X_test)
r2 = r2_score(y_test, predictions)
print('Test R^2 score:', r2)
# Out:
# Fitting 5 folds for each of 1280 candidates, totalling 6400 fits
# Runtime =  34.35629270800018
# Best params：{'colsample_bytree': 0.6, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.6}
# Best model score:0.1392881452912341
# Test R^2 score: 0.12572372997755876

# %% [markdown]
# # Lets see how XGBoost works for Residential data 2021 -> XGBoost on all areas

# %%
# Convert 'DateTime' to datetime if it's not already
berga_df_r['DateTime'] = pd.to_datetime(berga_df_r['DateTime'])
# Set 'DateTime' as index
berga_df_r.set_index('DateTime', inplace=True)
# Out:
# /var/folders/bl/02tnlb3j63n87b_hctf4mh380000gq/T/ipykernel_34624/3441394450.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   berga_df_r['DateTime'] = pd.to_datetime(berga_df_r['DateTime'])

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import xgboost as xgb
from sklearn.model_selection import GridSearchCV
import time
from sklearn.metrics import r2_score

# Resample to daily data
daily_data = berga_df_r.resample('D').agg({'Price':'mean', 'Power_Consumption':'mean'})

daily_data
# Out:
#                  Price  Power_Consumption
# DateTime
# 2021-01-01   36.262917           0.001786
# 2021-01-02   43.159167           0.001886
# 2021-01-03   27.283333           0.001951
# 2021-01-04   44.015833           0.002066
# 2021-01-05   47.370833           0.001998
# ...                ...                ...
# 2021-12-27  148.466667           0.002150
# 2021-12-28  111.252083           0.001867
# 2021-12-29  153.792083           0.001656
# 2021-12-30   68.722500           0.001535
# 2021-12-31   44.312917           0.001288
#
# [365 rows x 2 columns]

# %%
# Feature Engineering: Create new features based on the 'DateTime' index
daily_data['DayOfWeek'] = daily_data.index.dayofweek
daily_data['Month'] = daily_data.index.month

# Include these new features in your training and testing sets
X = daily_data[['Price', 'DayOfWeek', 'Month']]
y = daily_data['Power_Consumption']

# Split the resampled data into features and target
X_train, X_test, y_train, y_test = train_test_split(
    daily_data[['Price']],  # Features (2D array)
    daily_data['Power_Consumption'],  # Target (1D array)
    test_size=0.25, 
    random_state=42
)


#Normalize the feature data (Scaling the data)
scaler = StandardScaler()
# Fit the scaler on the training data and transform both training and testing data
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Start timer for runtime calculation
start = time.perf_counter()

# Define the parameter grid for the GridSearchCV
# Hyperparameter Tuning: Expand the search with a wider range of values
cv_params = {
    'n_estimators': [100, 250, 500, 750, 1000],
    'max_depth': [3, 5, 7, 9],
    'learning_rate': [0.01, 0.05, 0.1, 0.2],
    'subsample': [0.6, 0.7, 0.8, 0.9],
    'colsample_bytree': [0.6, 0.7, 0.8, 0.9],
}

# Initialize the XGBRegressor and GridSearchCV objects
xg = xgb.XGBRegressor()
optimized_GBM = GridSearchCV(
    estimator=xg, 
    param_grid=cv_params, 
    scoring='r2', 
    cv=5, 
    verbose=1, 
    n_jobs=-1
)

# Fit the GridSearchCV object to the training data
optimized_GBM.fit(X_train, y_train)

# End timer for runtime calculation
end = time.perf_counter()
runtime = end - start

# Output the results
print("Runtime = ", runtime)
print('Best params：{0}'.format(optimized_GBM.best_params_))
print('Best model score:{0}'.format(optimized_GBM.best_score_))

# Predict and evaluate the model using the test data (optional)
predictions = optimized_GBM.predict(X_test)
r2 = r2_score(y_test, predictions)
print('Test R^2 score:', r2)
# Out:
# Fitting 5 folds for each of 1280 candidates, totalling 6400 fits
# Runtime =  23.046197458999814
# Best params：{'colsample_bytree': 0.6, 'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 1000, 'subsample': 0.6}
# Best model score:0.1173785779560913
# Test R^2 score: 0.06412388749338283

# %% [markdown]
# # Xi code for Berga residential 2021

# %%
from sklearn.metrics import mean_squared_error 
import numpy as np
from sklearn.metrics import r2_score
from sklearn import metrics
import xgboost as xgb
from sklearn.model_selection import GridSearchCV
import time
from sklearn.model_selection import train_test_split
from pandas import DataFrame,Series
xtrain,xtest,ytrain,ytest = train_test_split(berga_df_r['Price'].values.reshape(-1, 1),berga_df_r['Power_Consumption'],test_size=0.25)
print("TRAIN:",xtrain.shape, "；  TEST:",xtest.shape)
print("TRAIN:",ytrain.shape, "；  TEST:",ytest.shape)
start = time.perf_counter()
cv_params = [
            {'n_estimators': [50,500,50],
             'max_depth':[1,15,1],
             'learning_rate':[0.1,0.2,0.3,0.4]}
              ]
other_params = {}

xg = xgb.XGBRegressor(**other_params)
optimized_GBM = GridSearchCV(estimator=xg, param_grid=cv_params, scoring='r2', cv=5, verbose=1, n_jobs=-1)
optimized_GBM.fit(xtrain, ytrain)
evalute_result = optimized_GBM.cv_results_['mean_test_score']
end = time.perf_counter()
runtime = end - start
print("Runtime = ", runtime)
#print('Results of each iteration:{0}'.format(evalute_result))
print('Best params：{0}'.format(optimized_GBM.best_params_))
print('Best model score:{0}'.format(optimized_GBM.best_score_))
# Out:
# TRAIN: (716238, 1) ；  TEST: (238746, 1)
# TRAIN: (716238,) ；  TEST: (238746,)
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# Runtime =  32.82743958399806
# Best params：{'learning_rate': 0.4, 'max_depth': 15, 'n_estimators': 50}
# Best model score:0.013730751856813116

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import numpy as np
import xgboost as xgb

# MAPE function
def mape(y_true, y_pred): 
    return np.mean(np.abs((y_pred - y_true) / y_true)) * 100

# Initialize XGBoost regressor with specified parameters
xg = xgb.XGBRegressor(learning_rate=0.1, max_delta_step=0, max_depth=1,
                      min_child_weight=3, n_estimators=500, n_jobs=-1)

# Fit the model to our training data
xg.fit(X_train, y_train)

# Predict the target on the test dataset
xg_pre = xg.predict(X_test)

# Calculate evaluation metrics
xg_mse = mean_squared_error(y_test, xg_pre)
xg_rmse = np.sqrt(xg_mse)
xg_mae = mean_absolute_error(y_test, xg_pre)
xg_mape = mape(y_test, xg_pre)
xg_r2 = r2_score(y_test, xg_pre)

# Print the evaluation metrics
print("xg_MSE:", xg_mse)
print("xg_RMSE:", xg_rmse)
print("xg_MAE:", xg_mae)
print("xg_MAPE:", xg_mape)
print("xg_score2:", xg_r2)
# Out:
# xg_MSE: 2.3161104378127473e-07
# xg_RMSE: 0.0004812598505810294
# xg_MAE: 0.0003699018443470865
# xg_MAPE: 23.83752761946895
# xg_score2: 0.01228349633309267

# %% [markdown]
# # ARIMA model for commercial data and year 2021 following the link https://machinelearningmastery.com/arima-for-time-series-forecasting-with-python/

# %%
# First convert the df you need (commercial_df_2021) to csv becasue you need it in the next block
commercial_df_2021.to_csv('data/commercial_df_2021.csv', index=True)

# %%
commercial_df_2021
# Out:
#                     DateTime    CUSTOMER         AREA ISPRIVATEPERSON  \
# 6944448  2021-01-01 00:00:00  1060753805  Kvarnholmen             Nej
# 6944449  2021-01-01 00:00:00  1060766019       Malmen             Nej
# 6944451  2021-01-01 00:00:00  1060616621       Malmen             Nej
# 6944452  2021-01-01 00:00:00  1060621516       Malmen             Nej
# 6944453  2021-01-01 00:00:00  1060601163  Kvarnholmen             Nej
# ...                      ...         ...          ...             ...
# 14619619 2021-12-31 23:00:00  1060598838  Kvarnholmen             Nej
# 14619620 2021-12-31 23:00:00  1060598788  Kvarnholmen             Nej
# 14619621 2021-12-31 23:00:00  1060604204  Kvarnholmen             Nej
# 14619622 2021-12-31 23:00:00  1060599041  Kvarnholmen             Nej
# 14619623 2021-12-31 23:00:00  1060603544  Kvarnholmen             Nej
#
#           Power_Consumption  One_Day_Power  One_Day_Power_NaN  \
# 6944448            0.001000       0.023940                  0
# ...

# %%
commercial_df_2021.dtypes
# Out:
# DateTime                     datetime64[ns]
# CUSTOMER                              int64
# AREA                                 object
# ISPRIVATEPERSON                      object
# Power_Consumption                   float64
# One_Day_Power                       float64
# One_Day_Power_NaN                     int64
# Air Temperature 1 Min_P19           float64
# Air Temperature 2 Max_P27           float64
# Air Temperature 2 Min_P26           float64
# Dew Point Temperature_P39           float64
# Precipitation_P7                    float64
# Relative Humidity_P6                float64
# Wind Speed_P4                       float64
# Price                               float64
# dtype: object

# %%
# !pip install statsmodels

# %%
# fit an ARIMA model and plot residual errors
from datetime import datetime
from pandas import read_csv
from pandas import DataFrame
from statsmodels.tsa.arima.model import ARIMA
from matplotlib import pyplot

# Define the date_parser function
def parser(x):
    return datetime.strptime(x, '%Y-%m-%d %H:%M:%S')

# Read the CSV file while parsing the 'DateTime' column as dates
series = read_csv('data/commercial_df_2021.csv', header=0, parse_dates=['DateTime'], index_col='DateTime', date_parser=parser)

# Select the 'Power_Consumption' column and make sure it is in float format
series = series['Power_Consumption'].astype(float)

series.index = series.index.to_period('M')

# fit model
model = ARIMA(series, order=(5,1,0))  # In the ARIMA(5,1,0) model, p is 5, which means that the model uses the five previous time points (lags) to predict the next time point.
model_fit = model.fit()

# summary of fit model
print(model_fit.summary())

# line plot of residuals
residuals = DataFrame(model_fit.resid)
residuals.plot()
pyplot.show()

# density plot of residuals
residuals.plot(kind='kde')
pyplot.show()

# summary stats of residuals
print(residuals.describe())
# Out:
# /var/folders/bl/02tnlb3j63n87b_hctf4mh380000gq/T/ipykernel_1205/3950272647.py:13: FutureWarning: The argument 'date_parser' is deprecated and will be removed in a future version. Please use 'date_format' instead, or read your data in as 'object' dtype and then call 'to_datetime'.
#   series = read_csv('data/commercial_df_2021.csv', header=0, parse_dates=['DateTime'], index_col='DateTime', date_parser=parser)
#                                SARIMAX Results
# ...
# Dep. Variable:      Power_Consumption   No. Observations:              5863080
# Model:                 ARIMA(5, 1, 0)   Log Likelihood            12342298.396
# Date:                Wed, 03 Apr 2024   AIC                      -24684584.793
# Time:                        18:17:31   BIC                      -24684503.288
# Sample:                    01-31-2021   HQIC                     -24684563.838
#                          - 12-31-2021
# Covariance Type:                  opg
# ...
